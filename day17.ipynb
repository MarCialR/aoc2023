# %%
from tools import get_puzzle, show_problem_1, show_problem_2

TODAY = 17
puzzle = get_puzzle(TODAY)
show_problem_1(puzzle)
# Out:
# https://adventofcode.com/2023/day/17
# ## --- Day 17: Clumsy Crucible ---
#
#
# The lava starts flowing rapidly once the Lava Production Facility is operational. As youleave, the reindeer offers you a parachute, allowing you to quickly reach Gear Island.
#
#
# As you descend, your bird's-eye view of Gear Island reveals why you had trouble finding anyone on your way up: half of Gear Island is empty, but the half below you is a giant factory city!
#
#
# You land near the gradually-filling pool of lava at the base of your new **lavafall** . Lavaducts will eventually carry the lava throughout the city, but to make use of it immediately, Elves are loading it into large [crucibles](https://en.wikipedia.org/wiki/Crucible) on wheels.
#
#
# The crucibles are top-heavy and pushed by hand. Unfortunately, the crucibles become very difficult to steer at high speeds, and so it can be hard to go in a straight line for very long.
#
#
# To get Desert Island the machine parts it needs as soon as possible, you'll need to find the best way to get the crucible **from the lava pool to the machine parts factory** . To do this, you need to minimize **heat loss** while choosing a route that doesn't require the crucible to go in a **straight line** for too long.
#
#
# Fortunately, the Elves here have a map (your puzzle input) that uses traffic patterns, ambient temperature, and hundreds of other parameters to calculate exactly how much heat loss can be expected for a crucible entering any particular city block.
#
#
# For example:
#
#
# ```
#  2413432311323
#  3215453535623
#  3255245654254
#  3446585845452
#  4546657867536
#  1438598798454
#  4457876987766
#  3637877979653
#  4654967986887
#  4564679986453
#  1224686865563
#  2546548887735
#  4322674655533
#
# ```
#
#
# Each city block is marked by a single digit that represents the **amount of heat loss if the crucible enters that block** . The starting point, the lava pool, is the top-left city block; the destination, the machine parts factory, is the bottom-right city block. (Because you already start in the top-left block, you don't incur that block's heat loss unless you leave that block and then return to it.)
#
#
# Because it is difficult to keep the top-heavy crucible going in a straight line for very long, it can move **at most three blocks** in a single direction before it must turn 90 degrees left or right. The crucible also can't reverse direction; after entering each city block, it may only turn left, continue straight, or turn right.
#
#
# One way to **minimize heat loss** is this path:
#
#
# >>^>>>v>>>vv>>vv>vvv>465496798688v456467998645v12246868655<v25465488877vv>```
#  2341323
#  32355623
#  3255245654
#  344658584552
#  45466578676
#  143859879844
#  445787698776
#  363787797965
#  43226746555
#
# ```
#
#
# This path never moves more than three consecutive blocks in the same direction and incurs a heat loss of only102``.
#
#
# Directing the crucible from the lava pool to the machine parts factory, but not moving more than three consecutive blocks in the same direction, **what is the least heat loss it can incur?**

# %%
class Node():
    """A node class for A* Pathfinding"""

    def __init__(self, parent=None, position=None):
        self.parent = parent
        self.position = position

        self.g = 0
        self.h = 0
        self.f = 0

    def __eq__(self, other):
        return self.position == other.position
    
    def __repr__(self):
        return f"Pos: {self.position} f:{self.f} g:{self.g} h:{self.h}"


def astar(maze, start, end):
    """Returns a list of tuples as a path from the given start to the given end in the given maze"""

    # Create start and end node
    start_node = Node(None, start)
    start_node.g = start_node.h = start_node.f = 0
    end_node = Node(None, end)
    end_node.g = end_node.h = end_node.f = 0

    # Initialize both open and closed list
    open_list = []
    closed_list = []

    # Add the start node
    open_list.append(start_node)

    # Loop until you find the end
    while len(open_list) > 0:


        # Get the current node
        current_node = open_list[0]
        current_index = 0
        
        #for index, item in enumerate(open_list):
        #    if item.f < current_node.f:
        #        current_node = item
        #        current_index = index

        # Pop current off open list, add to closed list
        open_list.pop(current_index)
        closed_list.append(current_node)

        print(f"Closed: {len(open_list)}   Open:{len(open_list)} ")

        # Found the goal
        if current_node.position == end_node.position:
            path = []
            current = current_node
            while current is not None:
                path.append(current.position)
                current = current.parent
            print(f" f:{current_node.f} g:{current_node.g} h:{current_node.h}")
            print ( path[::-1]) # Return reversed path
            continue

        # Generate children
        children = []
        for direction in [(0, -1), (0, 1), (-1, 0), (1, 0)]: # Non-diagonal adjacent squares

            # Get node position
            

            new_position = validate_new_position(current_node, direction, maze)

            if new_position:
                # Make sure walkable terrain
                #if maze[node_position[0]][node_position[1]] != 0:
                    #continue

                # Create new node
                new_node = Node(current_node, new_position)

                # Append
                children.append(new_node)

        print (f"\tDOING { current_node.position}")

        # Loop through children
        for child in children:

            # Child is on the closed list
            for closed_child in closed_list:
                if child == closed_child:
                    continue

            # Create the f, g, and h values
                
            print (f"child {maze[child.position[0]][child.position[1]]}")
            
            child.g = current_node.g + maze[child.position[0]][child.position[1]]
            child.h = ((child.position[0] - end_node.position[0]) ** 2) + ((child.position[1] - end_node.position[1]) ** 2)
            child.f = child.g + child.h

            # Child is already in the open list
            for open_node in open_list:
                if child.position == open_node.position:
                    if child.f < open_node.f:
                        print(f"{open_node}  {child}")
                        open_node.f = child.f
                        open_node.g = child.g
                        open_node.h = child.h
                        open_node.parent = child.parent
                    continue

            # Add the child to the open list
            open_list.append(child)

def validate_new_position(current_node, direction, maze):

    new_position = (current_node.position[0] + direction[0], current_node.position[1] + direction[1])
    
    # Make sure within range
    if new_position[0] > (len(maze) - 1) or new_position[0] < 0 or new_position[1] > (len(maze[len(maze)-1]) -1) or new_position[1] < 0:
        return False
    # make sure not going backwards
    if current_node.parent and new_position[0] == current_node.parent.position[0]    and new_position[1] == current_node.parent.position[1]:
        return False
     # make sure this is not the 4th straight line move
    if current_node.parent and current_node.parent.parent and current_node.parent.parent.parent: 
        for i in [0,1]:
            if new_position[i] == current_node.position[i] == current_node.parent.position[i] == current_node.parent.parent.position[i] == current_node.parent.parent.parent.position[i]: 
                print("Not for times straight please!!")
                return False
    return new_position


def main(maze):

    start = (0, 0)
    end = (len(maze)-1, len(maze[0])-1)

    path = astar(maze, start, end)
    print(path)


if __name__ == '__main__':
    maze = [[int(c) for c in x] for x in puzzle.test]
    main(maze)
# Out:
# Closed: 0   Open:0
# 	DOING (0, 0)
# child 4
# child 3
# Closed: 1   Open:1
# 	DOING (0, 1)
# child 1
# child 2
# Closed: 2   Open:2
# 	DOING (1, 0)
# child 2
# Pos: (1, 1) f:248 g:6 h:242  Pos: (1, 1) f:247 g:5 h:242
# child 3
# Closed: 3   Open:3
# 	DOING (0, 2)
# child 3
# child 1
# Closed: 4   Open:4
# 	DOING (1, 1)
# child 1
# child 4
# child 2
# Closed: 6   Open:6
# 	DOING (1, 1)
# child 1
# child 4
# child 2
# Closed: 8   Open:8
# 	DOING (2, 0)
# child 2
# child 3
# Closed: 9   Open:9
# Not for times straight please!!
# 	DOING (0, 3)
# child 5
# Closed: 9   Open:9
# 	DOING (1, 2)
# child 2
# child 5
# Pos: (1, 3) f:215 g:13 h:202  Pos: (1, 3) f:213 g:11 h:202
# child 5
# Closed: 11   Open:11
# 	DOING (1, 2)
# child 5
# child 1
# child 5
# Closed: 13   Open:13
# 	DOING (0, 1)
# child 2
# child 1
# Closed: 14   Open:14
# 	DOING (2, 1)
# child 3
# child 5
# child 4
# Closed: 16   Open:16
# 	DOING (1, 2)
# child 5
# child 1
# Pos: (0, 2) f:254 g:10 h:244  Pos: (0, 2) f:251 g:7 h:244
# child 5
# Pos: (2, 2) f:212 g:12 h:200  Pos: (2, 2) f:211 g:11 h:200
# Closed: 18   Open:18
# 	DOING (0, 1)
# child 2
# child 1
# Closed: 19   Open:19
# 	DOING (2, 1)
# child 3
# child 5
# child 4
# Closed: 21   Open:21
# 	DOING (2, 1)
# child 5
# child 2
# child 4
# Closed: 23   Open:23
# Not for times straight please!!
# 	DOING (3, 0)
# child 4
# Closed: 23   Open:23
# 	DOING (1, 3)
# child 4
# child 3
# child 5
# Closed: 25   Open:25
# 	DOING (1, 1)
# child 3
# child 4
# child 2
# Closed: 27   Open:27
# 	DOING (1, 3)
# child 4
# child 3
# child 5
# Closed: 29   Open:29
# 	DOING (2, 2)
# child 2
# child 5
# child 4
# Closed: 31   Open:31
# Not for times straight please!!
# 	DOING (1, 3)
# child 3
# child 5
# Closed: 32   Open:32
# 	DOING (0, 2)
# child 4
# Pos: (0, 1) f:277 g:12 h:265  Pos: (0, 1) f:276 g:11 h:265
# child 3
# Pos: (0, 3) f:239 g:14 h:225  Pos: (0, 3) f:235 g:10 h:225
# Pos: (0, 3) f:239 g:14 h:225  Pos: (0, 3) f:235 g:10 h:225
# Pos: (0, 3) f:239 g:14 h:225  Pos: (0, 3) f:235 g:10 h:225
# Closed: 33   Open:33
# 	DOING (2, 2)
# child 2
# child 5
# child 4
# Closed: 35   Open:35
# 	DOING (0, 0)
# child 3
# Closed: 35   Open:35
# 	DOING (0, 2)
# child 4
# child 3
# Closed: 36   Open:36
# 	DOING (2, 0)
# child 3
# Pos: (1, 0) f:279 g:14 h:265  Pos: (1, 0) f:278 g:13 h:265
# child 3
# Closed: 37   Open:37
# 	DOING (2, 2)
# child 2
# child 5
# child 4
# Closed: 39   Open:39
# 	DOING (3, 1)
# child 3
# child 4
# child 5
# Closed: 41   Open:41
# Not for times straight please!!
# 	DOING (1, 3)
# child 3
# child 5
# Closed: 42   Open:42
# 	DOING (0, 2)
# child 4
# child 3
# Pos: (0, 3) f:239 g:14 h:225  Pos: (0, 3) f:235 g:10 h:225
# Closed: 43   Open:43
# 	DOING (2, 2)
# child 2
# child 5
# child 4
# Closed: 45   Open:45
# 	DOING (0, 0)
# child 3
# Closed: 45   Open:45
# 	DOING (0, 2)
# child 3
# child 1
# Closed: 46   Open:46
# 	DOING (2, 0)
# child 3
# Pos: (1, 0) f:279 g:14 h:265  Pos: (1, 0) f:278 g:13 h:265
# child 3
# Pos: (3, 0) f:239 g:14 h:225  Pos: (3, 0) f:238 g:13 h:225
# Closed: 47   Open:47
# 	DOING (2, 2)
# child 5
# child 1
# child 4
# Closed: 49   Open:49
# 	DOING (3, 1)
# child 3
# child 4
# Pos: (3, 2) f:197 g:16 h:181  Pos: (3, 2) f:196 g:15 h:181
# child 5
# Closed: 51   Open:51
# 	DOING (2, 2)
# child 5
# child 1
# child 4
# Closed: 53   Open:53
# 	DOING (1, 1)
# child 3
# child 1
# Pos: (1, 2) f:234 g:13 h:221  Pos: (1, 2) f:232 g:11 h:221
# Pos: (1, 2) f:235 g:14 h:221  Pos: (1, 2) f:232 g:11 h:221
# child 4
# Closed: 55   Open:55
# 	DOING (3, 1)
# child 3
# child 4
# Pos: (3, 2) f:198 g:17 h:181  Pos: (3, 2) f:197 g:16 h:181
# child 5
# Closed: 57   Open:57
# 	DOING (3, 1)
# child 4
# child 2
# child 5
# Closed: 59   Open:59
# 	DOING (1, 4)
# child 5
# child 4
# child 2
# Closed: 61   Open:61
# 	DOING (0, 3)
# child 4
# Pos: (0, 4) f:227 g:19 h:208  Pos: (0, 4) f:222 g:14 h:208
# child 5
# Closed: 62   Open:62
# 	DOING (2, 3)
# child 5
# child 2
# child 6
# Closed: 64   Open:64
# 	DOING (1, 0)
# child 2
# child 3
# Closed: 65   Open:65
# 	DOING (0, 1)
# child 2
# child 2
# Closed: 66   Open:66
# 	DOING (2, 1)
# child 3
# Pos: (2, 0) f:258 g:14 h:244  Pos: (2, 0) f:257 g:13 h:244
# child 5
# Pos: (2, 2) f:221 g:21 h:200  Pos: (2, 2) f:215 g:15 h:200
# child 4
# Closed: 68   Open:68
# 	DOING (1, 4)
# child 5
# child 4
# child 2
# Pos: (2, 4) f:182 g:18 h:164  Pos: (2, 4) f:181 g:17 h:164
# Closed: 70   Open:70
# 	DOING (0, 3)
# child 4
# Pos: (0, 4) f:227 g:19 h:208  Pos: (0, 4) f:222 g:14 h:208
# child 5
# Closed: 71   Open:71
# 	DOING (2, 3)
# child 5
# child 2
# child 6
# Closed: 73   Open:73
# 	DOING (2, 1)
# child 3
# child 2
# child 4
# Closed: 75   Open:75
# 	DOING (2, 3)
# child 2
# child 5
# child 6
# Closed: 77   Open:77
# Not for times straight please!!
# 	DOING (3, 2)
# child 4
# child 6
# Pos: (3, 3) f:184 g:22 h:162  Pos: (3, 3) f:183 g:21 h:162
# Pos: (3, 3) f:184 g:22 h:162  Pos: (3, 3) f:183 g:21 h:162
# Pos: (3, 3) f:184 g:22 h:162  Pos: (3, 3) f:183 g:21 h:162
# Closed: 78   Open:78
# 	DOING (0, 3)
# child 4
# child 5
# Pos: (1, 3) f:223 g:21 h:202  Pos: (1, 3) f:217 g:15 h:202
# Closed: 79   Open:79
# 	DOING (2, 3)
# child 5
# child 2
# child 6
# Closed: 81   Open:81
# 	DOING (0, 1)
# child 2
# child 2
# Pos: (1, 1) f:257 g:15 h:242  Pos: (1, 1) f:255 g:13 h:242
# Closed: 82   Open:82
# 	DOING (0, 3)
# child 4
# child 5
# Closed: 83   Open:83
# 	DOING (2, 1)
# child 3
# child 2
# child 4
# Pos: (3, 1) f:221 g:19 h:202  Pos: (3, 1) f:219 g:17 h:202
# Closed: 85   Open:85
# 	DOING (2, 3)
# child 2
# child 5
# child 6
# Closed: 87   Open:87
# 	DOING (3, 2)
# child 4
# child 6
# Pos: (3, 3) f:184 g:22 h:162  Pos: (3, 3) f:183 g:21 h:162
# Pos: (3, 3) f:184 g:22 h:162  Pos: (3, 3) f:183 g:21 h:162
# child 4
# Closed: 89   Open:89
# 	DOING (1, 0)
# child 2
# child 2
# Closed: 90   Open:90
# 	DOING (0, 1)
# child 2
# Pos: (0, 0) f:303 g:15 h:288  Pos: (0, 0) f:301 g:13 h:288
# child 2
# Pos: (1, 1) f:257 g:15 h:242  Pos: (1, 1) f:255 g:13 h:242
# Pos: (1, 1) f:257 g:15 h:242  Pos: (1, 1) f:255 g:13 h:242
# Closed: 91   Open:91
# 	DOING (0, 3)
# child 4
# child 5
# Pos: (1, 3) f:223 g:21 h:202  Pos: (1, 3) f:217 g:15 h:202
# Closed: 92   Open:92
# 	DOING (1, 0)
# child 2
# child 2
# Closed: 93   Open:93
# 	DOING (3, 0)
# child 4
# Pos: (3, 1) f:221 g:19 h:202  Pos: (3, 1) f:219 g:17 h:202
# child 4
# Closed: 94   Open:94
# 	DOING (2, 1)
# child 3
# child 2
# child 4
# Closed: 96   Open:96
# 	DOING (2, 3)
# child 2
# child 5
# child 6
# Closed: 98   Open:98
# 	DOING (3, 2)
# child 4
# child 6
# Pos: (3, 3) f:184 g:22 h:162  Pos: (3, 3) f:183 g:21 h:162
# child 4
# Closed: 100   Open:100
# 	DOING (3, 0)
# child 4
# Pos: (3, 1) f:221 g:19 h:202  Pos: (3, 1) f:219 g:17 h:202
# child 4
# Closed: 101   Open:101
# 	DOING (3, 2)
# child 6
# child 5
# Pos: (2, 2) f:221 g:21 h:200  Pos: (2, 2) f:220 g:20 h:200
# Pos: (2, 2) f:221 g:21 h:200  Pos: (2, 2) f:220 g:20 h:200
# child 4
# Closed: 103   Open:103
# Not for times straight please!!
# 	DOING (4, 1)
# child 4
# child 4
# Closed: 104   Open:104
# 	DOING (0, 3)
# child 4
# child 5
# Pos: (1, 3) f:223 g:21 h:202  Pos: (1, 3) f:217 g:15 h:202
# Closed: 105   Open:105
# 	DOING (2, 3)
# child 5
# child 2
# child 6
# Closed: 107   Open:107
# 	DOING (0, 1)
# child 2
# Pos: (0, 0) f:303 g:15 h:288  Pos: (0, 0) f:301 g:13 h:288
# child 2
# Pos: (1, 1) f:257 g:15 h:242  Pos: (1, 1) f:255 g:13 h:242
# Pos: (1, 1) f:257 g:15 h:242  Pos: (1, 1) f:255 g:13 h:242
# Closed: 108   Open:108
# 	DOING (0, 3)
# child 4
# child 5
# Closed: 109   Open:109
# 	DOING (2, 1)
# child 3
# child 2
# child 4
# Closed: 111   Open:111
# 	DOING (2, 3)
# child 2
# child 5
# child 6
# Closed: 113   Open:113
# 	DOING (3, 2)
# child 4
# child 6
# Pos: (3, 3) f:184 g:22 h:162  Pos: (3, 3) f:183 g:21 h:162
# Pos: (3, 3) f:184 g:22 h:162  Pos: (3, 3) f:183 g:21 h:162
# child 4
# Pos: (4, 2) f:184 g:20 h:164  Pos: (4, 2) f:183 g:19 h:164
# Closed: 115   Open:115
# 	DOING (1, 0)
# child 2
# child 2
# Closed: 116   Open:116
# 	DOING (0, 3)
# child 4
# child 5
# Pos: (1, 3) f:223 g:21 h:202  Pos: (1, 3) f:220 g:18 h:202
# Closed: 117   Open:117
# 	DOING (1, 2)
# child 2
# Pos: (1, 1) f:257 g:15 h:242  Pos: (1, 1) f:255 g:13 h:242
# Pos: (1, 1) f:257 g:15 h:242  Pos: (1, 1) f:255 g:13 h:242
# child 5
# Pos: (1, 3) f:220 g:18 h:202  Pos: (1, 3) f:218 g:16 h:202
# Pos: (1, 3) f:220 g:18 h:202  Pos: (1, 3) f:218 g:16 h:202
# child 5
# Pos: (2, 2) f:220 g:20 h:200  Pos: (2, 2) f:216 g:16 h:200
# Pos: (2, 2) f:220 g:20 h:200  Pos: (2, 2) f:216 g:16 h:200
# Pos: (2, 2) f:220 g:20 h:200  Pos: (2, 2) f:216 g:16 h:200
# Pos: (2, 2) f:221 g:21 h:200  Pos: (2, 2) f:216 g:16 h:200
# Closed: 119   Open:119
# 	DOING (1, 0)
# child 2
# child 2
# Closed: 120   Open:120
# 	DOING (3, 0)
# child 4
# Pos: (3, 1) f:221 g:19 h:202  Pos: (3, 1) f:219 g:17 h:202
# child 4
# Pos: (4, 0) f:228 g:20 h:208  Pos: (4, 0) f:225 g:17 h:208
# Closed: 121   Open:121
# 	DOING (2, 3)
# child 2
# child 5
# child 6
# Closed: 123   Open:123
# 	DOING (1, 2)
# child 5
# Pos: (1, 3) f:224 g:22 h:202  Pos: (1, 3) f:218 g:16 h:202
# child 1
# child 5
# Closed: 125   Open:125
# 	DOING (3, 2)
# child 6
# Pos: (3, 3) f:185 g:23 h:162  Pos: (3, 3) f:183 g:21 h:162
# child 5
# child 4
# Closed: 127   Open:127
# 	DOING (3, 0)
# child 3
# child 4
# Closed: 128   Open:128
# 	DOING (3, 2)
# child 6
# child 5
# child 4
# Closed: 130   Open:130
# Not for times straight please!!
# 	DOING (4, 1)
# child 4
# child 4
# Closed: 131   Open:131
# Not for times straight please!!
# 	DOING (2, 3)
# child 5
# child 6
# Closed: 132   Open:132
# 	DOING (1, 2)
# child 5
# Pos: (1, 3) f:225 g:23 h:202  Pos: (1, 3) f:218 g:16 h:202
# child 1
# child 5
# Pos: (2, 2) f:220 g:20 h:200  Pos: (2, 2) f:216 g:16 h:200
# Pos: (2, 2) f:220 g:20 h:200  Pos: (2, 2) f:216 g:16 h:200
# Closed: 134   Open:134
# 	DOING (3, 2)
# child 6
# Pos: (3, 3) f:186 g:24 h:162  Pos: (3, 3) f:184 g:22 h:162
# child 5
# child 4
# Closed: 136   Open:136
# 	DOING (1, 0)
# child 2
# child 3
# Pos: (2, 0) f:261 g:17 h:244  Pos: (2, 0) f:260 g:16 h:244
# Closed: 137   Open:137
# 	DOING (1, 2)
# child 5
# child 1
# child 5
# Pos: (2, 2) f:221 g:21 h:200  Pos: (2, 2) f:216 g:16 h:200
# Closed: 139   Open:139
# 	DOING (0, 1)
# child 2
# child 1
# Closed: 140   Open:140
# 	DOING (3, 0)
# child 3
# child 4
# Pos: (4, 0) f:228 g:20 h:208  Pos: (4, 0) f:227 g:19 h:208
# Closed: 141   Open:141
# 	DOING (3, 2)
# child 6
# child 5
# child 4
# Closed: 143   Open:143
# 	DOING (4, 1)
# child 4
# child 4
# child 4
# Closed: 145   Open:145
# 	DOING (3, 2)
# child 6
# child 5
# child 4
# Closed: 147   Open:147
# 	DOING (2, 1)
# child 3
# child 5
# Pos: (2, 2) f:221 g:21 h:200  Pos: (2, 2) f:220 g:20 h:200
# Pos: (2, 2) f:222 g:22 h:200  Pos: (2, 2) f:220 g:20 h:200
# child 2
# Closed: 149   Open:149
# 	DOING (4, 1)
# child 4
# child 4
# child 4
# Closed: 151   Open:151
# Not for times straight please!!
# 	DOING (1, 5)
# child 3
# child 4
# Closed: 152   Open:152
# 	DOING (0, 4)
# child 3
# Pos: (0, 5) f:216 g:23 h:193  Pos: (0, 5) f:210 g:17 h:193
# child 4
# Closed: 153   Open:153
# 	DOING (2, 4)
# child 5
# child 4
# Pos: (2, 5) f:173 g:24 h:149  Pos: (2, 5) f:170 g:21 h:149
# child 5
# Closed: 155   Open:155
# 	DOING (0, 4)
# child 3
# child 4
# Closed: 156   Open:156
# 	DOING (1, 3)
# child 1
# child 4
# child 5
# Pos: (2, 3) f:203 g:22 h:181  Pos: (2, 3) f:201 g:20 h:181
# Closed: 158   Open:158
# 	DOING (2, 2)
# child 5
# child 1
# child 4
# Closed: 160   Open:160
# 	DOING (2, 4)
# child 5
# child 4
# child 5
# Closed: 162   Open:162
# 	DOING (3, 3)
# child 5
# child 5
# child 6
# Closed: 164   Open:164
# 	DOING (0, 0)
# child 4
# Closed: 164   Open:164
# 	DOING (2, 0)
# child 3
# child 3
# Closed: 165   Open:165
# 	DOING (0, 0)
# child 3
# Closed: 165   Open:165
# 	DOING (1, 1)
# child 3
# child 1
# Pos: (1, 2) f:237 g:16 h:221  Pos: (1, 2) f:235 g:14 h:221
# Pos: (1, 2) f:237 g:16 h:221  Pos: (1, 2) f:235 g:14 h:221
# child 2
# Closed: 167   Open:167
# 	DOING (2, 0)
# child 3
# child 3
# Closed: 168   Open:168
# 	DOING (2, 2)
# child 5
# Pos: (2, 3) f:203 g:22 h:181  Pos: (2, 3) f:201 g:20 h:181
# Pos: (2, 3) f:207 g:26 h:181  Pos: (2, 3) f:201 g:20 h:181
# child 1
# child 4
# Closed: 170   Open:170
# 	DOING (3, 1)
# child 3
# child 4
# Pos: (3, 2) f:200 g:19 h:181  Pos: (3, 2) f:199 g:18 h:181
# Pos: (3, 2) f:200 g:19 h:181  Pos: (3, 2) f:199 g:18 h:181
# child 5
# Closed: 172   Open:172
# Not for times straight please!!
# 	DOING (1, 5)
# child 3
# child 4
# Closed: 173   Open:173
# 	DOING (0, 4)
# child 3
# Pos: (0, 5) f:216 g:23 h:193  Pos: (0, 5) f:210 g:17 h:193
# child 4
# Pos: (1, 4) f:204 g:19 h:185  Pos: (1, 4) f:203 g:18 h:185
# Closed: 174   Open:174
# 	DOING (2, 4)
# child 5
# child 4
# Pos: (2, 5) f:173 g:24 h:149  Pos: (2, 5) f:170 g:21 h:149
# child 5
# Pos: (3, 4) f:171 g:26 h:145  Pos: (3, 4) f:167 g:22 h:145
# Closed: 176   Open:176
# 	DOING (0, 4)
# child 3
# child 4
# Closed: 177   Open:177
# 	DOING (1, 3)
# child 1
# child 4
# child 5
# Pos: (2, 3) f:203 g:22 h:181  Pos: (2, 3) f:201 g:20 h:181
# Closed: 179   Open:179
# 	DOING (2, 2)
# child 2
# child 5
# child 4
# Closed: 181   Open:181
# 	DOING (2, 4)
# child 4
# child 4
# child 5
# Closed: 183   Open:183
# 	DOING (3, 3)
# child 5
# child 5
# child 6
# Closed: 185   Open:185
# 	DOING (2, 0)
# child 3
# child 3
# Closed: 186   Open:186
# 	DOING (1, 1)
# child 3
# Pos: (1, 0) f:284 g:19 h:265  Pos: (1, 0) f:281 g:16 h:265
# child 1
# Pos: (1, 2) f:237 g:16 h:221  Pos: (1, 2) f:235 g:14 h:221
# Pos: (1, 2) f:237 g:16 h:221  Pos: (1, 2) f:235 g:14 h:221
# child 2
# Pos: (2, 1) f:239 g:18 h:221  Pos: (2, 1) f:236 g:15 h:221
# Closed: 188   Open:188
# 	DOING (3, 1)
# child 3
# child 4
# child 5
# Closed: 190   Open:190
# 	DOING (2, 4)
# child 4
# child 4
# child 5
# Pos: (3, 4) f:171 g:26 h:145  Pos: (3, 4) f:168 g:23 h:145
# Closed: 192   Open:192
# 	DOING (1, 3)
# child 1
# child 4
# Pos: (1, 4) f:207 g:22 h:185  Pos: (1, 4) f:204 g:19 h:185
# Pos: (1, 4) f:207 g:22 h:185  Pos: (1, 4) f:204 g:19 h:185
# child 5
# Pos: (2, 3) f:202 g:21 h:181  Pos: (2, 3) f:201 g:20 h:181
# Pos: (2, 3) f:207 g:26 h:181  Pos: (2, 3) f:201 g:20 h:181
# Closed: 194   Open:194
# 	DOING (3, 3)
# child 5
# child 5
# child 6
# Closed: 196   Open:196
# 	DOING (3, 1)
# child 3
# child 4
# child 5
# Closed: 198   Open:198
# 	DOING (3, 3)
# child 5
# child 5
# child 6
# Closed: 200   Open:200
# 	DOING (0, 4)
# child 3
# child 4
# Pos: (1, 4) f:204 g:19 h:185  Pos: (1, 4) f:203 g:18 h:185
# Pos: (1, 4) f:204 g:19 h:185  Pos: (1, 4) f:203 g:18 h:185
# Pos: (1, 4) f:204 g:19 h:185  Pos: (1, 4) f:203 g:18 h:185
# Pos: (1, 4) f:204 g:19 h:185  Pos: (1, 4) f:203 g:18 h:185
# Closed: 201   Open:201
# 	DOING (1, 3)
# child 1
# child 4
# child 5
# Pos: (2, 3) f:207 g:26 h:181  Pos: (2, 3) f:201 g:20 h:181
# Pos: (2, 3) f:207 g:26 h:181  Pos: (2, 3) f:201 g:20 h:181
# Closed: 203   Open:203
# 	DOING (2, 2)
# child 2
# child 5
# child 4
# Pos: (3, 2) f:202 g:21 h:181  Pos: (3, 2) f:201 g:20 h:181
# Pos: (3, 2) f:202 g:21 h:181  Pos: (3, 2) f:201 g:20 h:181
# Closed: 205   Open:205
# 	DOING (2, 4)
# child 4
# child 4
# child 5
# Pos: (3, 4) f:171 g:26 h:145  Pos: (3, 4) f:168 g:23 h:145
# Pos: (3, 4) f:171 g:26 h:145  Pos: (3, 4) f:168 g:23 h:145
# Closed: 207   Open:207
# 	DOING (3, 3)
# child 5
# child 5
# child 6
# Closed: 209   Open:209
# 	DOING (0, 0)
# child 3
# Closed: 209   Open:209
# 	DOING (1, 1)
# child 3
# child 1
# Pos: (1, 2) f:237 g:16 h:221  Pos: (1, 2) f:235 g:14 h:221
# Pos: (1, 2) f:237 g:16 h:221  Pos: (1, 2) f:235 g:14 h:221
# child 2
# Pos: (2, 1) f:239 g:18 h:221  Pos: (2, 1) f:236 g:15 h:221
# Closed: 211   Open:211
# 	DOING (0, 4)
# child 3
# child 4
# Pos: (1, 4) f:204 g:19 h:185  Pos: (1, 4) f:203 g:18 h:185
# Pos: (1, 4) f:207 g:22 h:185  Pos: (1, 4) f:203 g:18 h:185
# Closed: 212   Open:212
# 	DOING (1, 3)
# child 1
# child 4
# child 5
# Pos: (2, 3) f:202 g:21 h:181  Pos: (2, 3) f:201 g:20 h:181
# Pos: (2, 3) f:207 g:26 h:181  Pos: (2, 3) f:201 g:20 h:181
# Closed: 214   Open:214
# 	DOING (2, 0)
# child 3
# child 3
# Pos: (3, 0) f:245 g:20 h:225  Pos: (3, 0) f:244 g:19 h:225
# Pos: (3, 0) f:245 g:20 h:225  Pos: (3, 0) f:244 g:19 h:225
# Closed: 215   Open:215
# 	DOING (1, 1)
# child 3
# Pos: (1, 0) f:284 g:19 h:265  Pos: (1, 0) f:281 g:16 h:265
# child 1
# Pos: (1, 2) f:237 g:16 h:221  Pos: (1, 2) f:235 g:14 h:221
# child 2
# Closed: 217   Open:217
# 	DOING (3, 1)
# child 3
# child 4
# child 5
# Closed: 219   Open:219
# 	DOING (2, 4)
# child 4
# child 4
# child 5
# Pos: (3, 4) f:171 g:26 h:145  Pos: (3, 4) f:168 g:23 h:145
# Closed: 221   Open:221
# 	DOING (1, 3)
# child 1
# child 4
# Pos: (1, 4) f:207 g:22 h:185  Pos: (1, 4) f:204 g:19 h:185
# child 5
# Closed: 223   Open:223
# 	DOING (3, 3)
# child 5
# child 5
# child 6
# Closed: 225   Open:225
# 	DOING (3, 1)
# child 4
# child 2
# child 5
# Closed: 227   Open:227
# 	DOING (3, 3)
# child 5
# child 5
# child 6
# Closed: 229   Open:229
# Not for times straight please!!
# 	DOING (4, 2)
# child 5
# child 6
# Pos: (4, 3) f:172 g:27 h:145  Pos: (4, 3) f:170 g:25 h:145
# Pos: (4, 3) f:172 g:27 h:145  Pos: (4, 3) f:170 g:25 h:145
# Pos: (4, 3) f:172 g:27 h:145  Pos: (4, 3) f:170 g:25 h:145
# Pos: (4, 3) f:172 g:27 h:145  Pos: (4, 3) f:170 g:25 h:145
# Pos: (4, 3) f:172 g:27 h:145  Pos: (4, 3) f:170 g:25 h:145
# Pos: (4, 3) f:172 g:27 h:145  Pos: (4, 3) f:170 g:25 h:145
# Pos: (4, 3) f:172 g:27 h:145  Pos: (4, 3) f:170 g:25 h:145
# Closed: 230   Open:230
# 	DOING (1, 1)
# child 3
# child 1
# Pos: (1, 2) f:237 g:16 h:221  Pos: (1, 2) f:235 g:14 h:221
# child 2
# Pos: (2, 1) f:240 g:19 h:221  Pos: (2, 1) f:236 g:15 h:221
# Closed: 232   Open:232
# 	DOING (0, 0)
# child 3
# Closed: 232   Open:232
# 	DOING (0, 0)
# child 3
# Closed: 232   Open:232
# 	DOING (1, 1)
# child 3
# child 1
# child 2
# Closed: 234   Open:234
# 	DOING (0, 4)
# child 3
# child 4
# Pos: (1, 4) f:204 g:19 h:185  Pos: (1, 4) f:203 g:18 h:185
# Pos: (1, 4) f:204 g:19 h:185  Pos: (1, 4) f:203 g:18 h:185
# Pos: (1, 4) f:204 g:19 h:185  Pos: (1, 4) f:203 g:18 h:185
# Closed: 235   Open:235
# 	DOING (1, 3)
# child 1
# child 4
# child 5
# Pos: (2, 3) f:207 g:26 h:181  Pos: (2, 3) f:201 g:20 h:181
# Pos: (2, 3) f:207 g:26 h:181  Pos: (2, 3) f:201 g:20 h:181
# Closed: 237   Open:237
# 	DOING (1, 1)
# child 3
# child 1
# Pos: (1, 2) f:237 g:16 h:221  Pos: (1, 2) f:235 g:14 h:221
# child 2
# Closed: 239   Open:239
# 	DOING (0, 0)
# child 3
# Closed: 239   Open:239
# 	DOING (3, 1)
# child 4
# child 2
# child 5
# Pos: (4, 1) f:209 g:24 h:185  Pos: (4, 1) f:207 g:22 h:185
# Closed: 241   Open:241
# 	DOING (4, 0)
# child 5
# child 1
# Closed: 242   Open:242
# 	DOING (2, 0)
# child 3
# child 3
# Pos: (3, 0) f:245 g:20 h:225  Pos: (3, 0) f:244 g:19 h:225
# Closed: 243   Open:243
# 	DOING (1, 1)
# child 3
# Pos: (1, 0) f:284 g:19 h:265  Pos: (1, 0) f:281 g:16 h:265
# child 1
# child 2
# Pos: (2, 1) f:240 g:19 h:221  Pos: (2, 1) f:236 g:15 h:221
# Closed: 245   Open:245
# 	DOING (3, 1)
# child 3
# child 4
# child 5
# Closed: 247   Open:247
# 	DOING (2, 4)
# child 4
# child 4
# child 5
# Pos: (3, 4) f:171 g:26 h:145  Pos: (3, 4) f:168 g:23 h:145
# Pos: (3, 4) f:171 g:26 h:145  Pos: (3, 4) f:168 g:23 h:145
# Closed: 249   Open:249
# 	DOING (1, 3)
# child 1
# child 4
# Pos: (1, 4) f:207 g:22 h:185  Pos: (1, 4) f:204 g:19 h:185
# child 5
# Closed: 251   Open:251
# 	DOING (3, 3)
# child 5
# child 5
# child 6
# Closed: 253   Open:253
# 	DOING (3, 1)
# child 4
# child 2
# child 5
# Closed: 255   Open:255
# 	DOING (3, 3)
# child 5
# child 5
# child 6
# Closed: 257   Open:257
# Not for times straight please!!
# 	DOING (4, 2)
# child 5
# child 6
# Pos: (4, 3) f:172 g:27 h:145  Pos: (4, 3) f:170 g:25 h:145
# Pos: (4, 3) f:172 g:27 h:145  Pos: (4, 3) f:170 g:25 h:145
# Closed: 258   Open:258
# 	DOING (3, 1)
# child 4
# child 2
# child 5
# Pos: (4, 1) f:209 g:24 h:185  Pos: (4, 1) f:207 g:22 h:185
# Closed: 260   Open:260
# 	DOING (4, 0)
# child 5
# child 1
# Closed: 261   Open:261
# 	DOING (3, 3)
# child 5
# child 5
# child 6
# Closed: 263   Open:263
# 	DOING (2, 2)
# child 2
# Pos: (2, 1) f:240 g:19 h:221  Pos: (2, 1) f:239 g:18 h:221
# Pos: (2, 1) f:240 g:19 h:221  Pos: (2, 1) f:239 g:18 h:221
# child 5
# Pos: (2, 3) f:207 g:26 h:181  Pos: (2, 3) f:202 g:21 h:181
# Pos: (2, 3) f:207 g:26 h:181  Pos: (2, 3) f:202 g:21 h:181
# Pos: (2, 3) f:207 g:26 h:181  Pos: (2, 3) f:202 g:21 h:181
# child 4
# Pos: (3, 2) f:202 g:21 h:181  Pos: (3, 2) f:201 g:20 h:181
# Pos: (3, 2) f:202 g:21 h:181  Pos: (3, 2) f:201 g:20 h:181
# Pos: (3, 2) f:202 g:21 h:181  Pos: (3, 2) f:201 g:20 h:181
# Pos: (3, 2) f:202 g:21 h:181  Pos: (3, 2) f:201 g:20 h:181
# Pos: (3, 2) f:202 g:21 h:181  Pos: (3, 2) f:201 g:20 h:181
# Pos: (3, 2) f:202 g:21 h:181  Pos: (3, 2) f:201 g:20 h:181
# Closed: 265   Open:265
# 	DOING (4, 2)
# child 5
# child 6
# Pos: (4, 3) f:172 g:27 h:145  Pos: (4, 3) f:170 g:25 h:145
# child 3
# Closed: 267   Open:267
# 	DOING (4, 0)
# child 5
# Pos: (4, 1) f:209 g:24 h:185  Pos: (4, 1) f:207 g:22 h:185
# child 1
# Closed: 268   Open:268
# Not for times straight please!!
# 	DOING (4, 2)
# child 5
# child 6
# Closed: 269   Open:269
# 	DOING (0, 4)
# child 3
# child 4
# Pos: (1, 4) f:204 g:19 h:185  Pos: (1, 4) f:203 g:18 h:185
# Pos: (1, 4) f:204 g:19 h:185  Pos: (1, 4) f:203 g:18 h:185
# Pos: (1, 4) f:204 g:19 h:185  Pos: (1, 4) f:203 g:18 h:185
# Closed: 270   Open:270
# 	DOING (1, 3)
# child 1
# child 4
# child 5
# Pos: (2, 3) f:202 g:21 h:181  Pos: (2, 3) f:201 g:20 h:181
# Pos: (2, 3) f:202 g:21 h:181  Pos: (2, 3) f:201 g:20 h:181
# Pos: (2, 3) f:202 g:21 h:181  Pos: (2, 3) f:201 g:20 h:181
# Pos: (2, 3) f:202 g:21 h:181  Pos: (2, 3) f:201 g:20 h:181
# Closed: 272   Open:272
# 	DOING (2, 2)
# child 2
# child 5
# child 4
# Closed: 274   Open:274
# 	DOING (2, 4)
# child 4
# child 4
# child 5
# Pos: (3, 4) f:171 g:26 h:145  Pos: (3, 4) f:168 g:23 h:145
# Pos: (3, 4) f:171 g:26 h:145  Pos: (3, 4) f:168 g:23 h:145
# Pos: (3, 4) f:171 g:26 h:145  Pos: (3, 4) f:168 g:23 h:145
# Closed: 276   Open:276
# 	DOING (3, 3)
# child 5
# child 5
# child 6
# Closed: 278   Open:278
# 	DOING (0, 0)
# child 3
# Closed: 278   Open:278
# 	DOING (1, 1)
# child 3
# child 1
# Pos: (1, 2) f:237 g:16 h:221  Pos: (1, 2) f:235 g:14 h:221
# Pos: (1, 2) f:237 g:16 h:221  Pos: (1, 2) f:235 g:14 h:221
# child 2
# Pos: (2, 1) f:239 g:18 h:221  Pos: (2, 1) f:236 g:15 h:221
# Pos: (2, 1) f:239 g:18 h:221  Pos: (2, 1) f:236 g:15 h:221
# Pos: (2, 1) f:239 g:18 h:221  Pos: (2, 1) f:236 g:15 h:221
# Pos: (2, 1) f:239 g:18 h:221  Pos: (2, 1) f:236 g:15 h:221
# Closed: 280   Open:280
# 	DOING (0, 4)
# child 3
# child 4
# Pos: (1, 4) f:204 g:19 h:185  Pos: (1, 4) f:203 g:18 h:185
# Pos: (1, 4) f:207 g:22 h:185  Pos: (1, 4) f:203 g:18 h:185
# Closed: 281   Open:281
# 	DOING (1, 3)
# child 1
# child 4
# child 5
# Pos: (2, 3) f:202 g:21 h:181  Pos: (2, 3) f:201 g:20 h:181
# Pos: (2, 3) f:207 g:26 h:181  Pos: (2, 3) f:201 g:20 h:181
# Closed: 283   Open:283
# 	DOING (2, 0)
# child 3
# child 3
# Pos: (3, 0) f:245 g:20 h:225  Pos: (3, 0) f:244 g:19 h:225
# Closed: 284   Open:284
# 	DOING (1, 1)
# child 3
# Pos: (1, 0) f:284 g:19 h:265  Pos: (1, 0) f:281 g:16 h:265
# child 4
# child 2
# Closed: 286   Open:286
# 	DOING (3, 1)
# child 3
# child 4
# child 5
# Pos: (4, 1) f:209 g:24 h:185  Pos: (4, 1) f:207 g:22 h:185
# Closed: 288   Open:288
# 	DOING (2, 4)
# child 4
# child 4
# child 5
# Pos: (3, 4) f:171 g:26 h:145  Pos: (3, 4) f:168 g:23 h:145
# Closed: 290   Open:290
# 	DOING (1, 3)
# child 4
# Pos: (1, 4) f:207 g:22 h:185  Pos: (1, 4) f:205 g:20 h:185
# child 3
# child 5
# Closed: 292   Open:292
# 	DOING (3, 3)
# child 5
# child 5
# child 6
# Closed: 294   Open:294
# 	DOING (3, 1)
# child 4
# child 2
# child 5
# Closed: 296   Open:296
# 	DOING (3, 3)
# child 5
# child 5
# child 6
# Closed: 298   Open:298
# Not for times straight please!!
# 	DOING (4, 2)
# child 5
# child 6
# Pos: (4, 3) f:172 g:27 h:145  Pos: (4, 3) f:170 g:25 h:145
# Pos: (4, 3) f:172 g:27 h:145  Pos: (4, 3) f:170 g:25 h:145
# Pos: (4, 3) f:172 g:27 h:145  Pos: (4, 3) f:170 g:25 h:145
# Closed: 299   Open:299
# 	DOING (1, 1)
# child 3
# child 4
# child 2
# Pos: (2, 1) f:240 g:19 h:221  Pos: (2, 1) f:236 g:15 h:221
# Closed: 301   Open:301
# 	DOING (0, 0)
# child 4
# Closed: 301   Open:301
# Not for times straight please!!
# 	DOING (0, 4)
# child 4
# Closed: 301   Open:301
# 	DOING (1, 3)
# child 4
# Pos: (1, 4) f:206 g:21 h:185  Pos: (1, 4) f:205 g:20 h:185
# child 3
# child 5
# Pos: (2, 3) f:207 g:26 h:181  Pos: (2, 3) f:202 g:21 h:181
# Pos: (2, 3) f:207 g:26 h:181  Pos: (2, 3) f:202 g:21 h:181
# Closed: 303   Open:303
# 	DOING (1, 1)
# child 3
# child 4
# Pos: (0, 1) f:284 g:19 h:265  Pos: (0, 1) f:282 g:17 h:265
# child 2
# Closed: 305   Open:305
# 	DOING (1, 3)
# child 4
# child 3
# child 5
# Closed: 307   Open:307
# 	DOING (2, 2)
# child 2
# child 5
# child 4
# Pos: (3, 2) f:202 g:21 h:181  Pos: (3, 2) f:201 g:20 h:181
# Pos: (3, 2) f:202 g:21 h:181  Pos: (3, 2) f:201 g:20 h:181
# Closed: 309   Open:309
# 	DOING (1, 1)
# child 1
# child 4
# child 2
# Pos: (2, 1) f:239 g:18 h:221  Pos: (2, 1) f:238 g:17 h:221
# Closed: 311   Open:311
# 	DOING (0, 0)
# child 4
# Closed: 311   Open:311
# 	DOING (3, 1)
# child 4
# child 2
# child 5
# Pos: (4, 1) f:209 g:24 h:185  Pos: (4, 1) f:207 g:22 h:185
# Closed: 313   Open:313
# 	DOING (4, 0)
# child 5
# child 1
# Closed: 314   Open:314
# Not for times straight please!!
# 	DOING (2, 4)
# child 4
# child 5
# Pos: (3, 4) f:171 g:26 h:145  Pos: (3, 4) f:169 g:24 h:145
# Pos: (3, 4) f:171 g:26 h:145  Pos: (3, 4) f:169 g:24 h:145
# Closed: 315   Open:315
# 	DOING (1, 3)
# child 4
# Pos: (1, 4) f:208 g:23 h:185  Pos: (1, 4) f:205 g:20 h:185
# child 3
# child 5
# Closed: 317   Open:317
# 	DOING (3, 3)
# child 5
# child 5
# child 6
# Closed: 319   Open:319
# 	DOING (1, 3)
# child 4
# child 3
# child 5
# Pos: (2, 3) f:207 g:26 h:181  Pos: (2, 3) f:202 g:21 h:181
# Closed: 321   Open:321
# 	DOING (0, 2)
# child 4
# Pos: (0, 1) f:282 g:17 h:265  Pos: (0, 1) f:281 g:16 h:265
# Pos: (0, 1) f:282 g:17 h:265  Pos: (0, 1) f:281 g:16 h:265
# Pos: (0, 1) f:282 g:17 h:265  Pos: (0, 1) f:281 g:16 h:265
# Pos: (0, 1) f:282 g:17 h:265  Pos: (0, 1) f:281 g:16 h:265
# Pos: (0, 1) f:282 g:17 h:265  Pos: (0, 1) f:281 g:16 h:265
# Pos: (0, 1) f:284 g:19 h:265  Pos: (0, 1) f:281 g:16 h:265
# Pos: (0, 1) f:284 g:19 h:265  Pos: (0, 1) f:281 g:16 h:265
# child 3
# Pos: (0, 3) f:244 g:19 h:225  Pos: (0, 3) f:240 g:15 h:225
# Pos: (0, 3) f:244 g:19 h:225  Pos: (0, 3) f:240 g:15 h:225
# Pos: (0, 3) f:244 g:19 h:225  Pos: (0, 3) f:240 g:15 h:225
# Pos: (0, 3) f:244 g:19 h:225  Pos: (0, 3) f:240 g:15 h:225
# Pos: (0, 3) f:244 g:19 h:225  Pos: (0, 3) f:240 g:15 h:225
# Closed: 322   Open:322
# 	DOING (2, 2)
# child 2
# Pos: (2, 1) f:240 g:19 h:221  Pos: (2, 1) f:239 g:18 h:221
# child 5
# child 4
# Pos: (3, 2) f:202 g:21 h:181  Pos: (3, 2) f:201 g:20 h:181
# Closed: 324   Open:324
# 	DOING (3, 3)
# child 5
# child 5
# child 6
# Closed: 326   Open:326
# 	DOING (2, 2)
# child 2
# child 5
# Pos: (2, 3) f:207 g:26 h:181  Pos: (2, 3) f:202 g:21 h:181
# child 4
# Closed: 328   Open:328
# 	DOING (4, 2)
# child 5
# child 6
# Pos: (4, 3) f:172 g:27 h:145  Pos: (4, 3) f:170 g:25 h:145
# Pos: (4, 3) f:172 g:27 h:145  Pos: (4, 3) f:170 g:25 h:145
# child 3
# Closed: 330   Open:330
# 	DOING (2, 0)
# child 2
# child 3
# Pos: (3, 0) f:245 g:20 h:225  Pos: (3, 0) f:244 g:19 h:225
# Closed: 331   Open:331
# 	DOING (4, 0)
# child 5
# Pos: (4, 1) f:209 g:24 h:185  Pos: (4, 1) f:208 g:23 h:185
# child 1
# Closed: 332   Open:332
# 	DOING (3, 3)
# child 5
# child 5
# child 6
# Closed: 334   Open:334
# 	DOING (2, 2)
# child 2
# child 5
# Pos: (2, 3) f:207 g:26 h:181  Pos: (2, 3) f:202 g:21 h:181
# child 4
# Closed: 336   Open:336
# 	DOING (4, 2)
# child 5
# child 6
# Pos: (4, 3) f:172 g:27 h:145  Pos: (4, 3) f:170 g:25 h:145
# child 3
# Closed: 338   Open:338
# 	DOING (4, 0)
# child 5
# child 1
# Closed: 339   Open:339
# 	DOING (4, 2)
# child 6
# child 4
# child 3
# Closed: 341   Open:341
# 	DOING (1, 3)
# child 4
# child 3
# child 5
# Closed: 343   Open:343
# 	DOING (3, 3)
# child 5
# child 5
# child 6
# Closed: 345   Open:345
# 	DOING (1, 3)
# child 4
# child 3
# child 5
# Pos: (2, 3) f:208 g:27 h:181  Pos: (2, 3) f:202 g:21 h:181
# Closed: 347   Open:347
# 	DOING (0, 2)
# child 4
# child 3
# Pos: (0, 3) f:244 g:19 h:225  Pos: (0, 3) f:240 g:15 h:225
# Pos: (0, 3) f:244 g:19 h:225  Pos: (0, 3) f:240 g:15 h:225
# Closed: 348   Open:348
# 	DOING (2, 2)
# child 2
# child 5
# child 4
# Pos: (3, 2) f:205 g:24 h:181  Pos: (3, 2) f:201 g:20 h:181
# Closed: 350   Open:350
# 	DOING (3, 3)
# child 5
# child 5
# child 6
# Closed: 352   Open:352
# 	DOING (2, 2)
# child 2
# child 5
# Pos: (2, 3) f:208 g:27 h:181  Pos: (2, 3) f:202 g:21 h:181
# child 4
# Closed: 354   Open:354
# 	DOING (4, 2)
# child 5
# child 6
# Pos: (4, 3) f:173 g:28 h:145  Pos: (4, 3) f:171 g:26 h:145
# Pos: (4, 3) f:173 g:28 h:145  Pos: (4, 3) f:171 g:26 h:145
# child 3
# Closed: 356   Open:356
# 	DOING (0, 0)
# child 4
# Closed: 356   Open:356
# 	DOING (2, 0)
# child 2
# child 3
# Closed: 357   Open:357
# 	DOING (1, 3)
# child 4
# child 3
# child 5
# Closed: 359   Open:359
# 	DOING (0, 2)
# child 4
# Pos: (0, 1) f:284 g:19 h:265  Pos: (0, 1) f:281 g:16 h:265
# child 3
# Pos: (0, 3) f:244 g:19 h:225  Pos: (0, 3) f:240 g:15 h:225
# Closed: 360   Open:360
# 	DOING (2, 2)
# child 2
# child 5
# child 4
# Closed: 362   Open:362
# 	DOING (0, 0)
# child 3
# Closed: 362   Open:362
# 	DOING (0, 2)
# child 3
# child 1
# Closed: 363   Open:363
# 	DOING (2, 0)
# child 2
# child 3
# Closed: 364   Open:364
# 	DOING (4, 0)
# child 5
# Pos: (4, 1) f:210 g:25 h:185  Pos: (4, 1) f:209 g:24 h:185
# child 1
# Closed: 365   Open:365
# 	DOING (3, 3)
# child 5
# child 5
# child 6
# Closed: 367   Open:367
# 	DOING (2, 2)
# child 5
# Pos: (2, 3) f:208 g:27 h:181  Pos: (2, 3) f:206 g:25 h:181
# child 1
# child 4
# Closed: 369   Open:369
# 	DOING (4, 2)
# child 5
# child 6
# Pos: (4, 3) f:173 g:28 h:145  Pos: (4, 3) f:171 g:26 h:145
# child 3
# Closed: 371   Open:371
# 	DOING (4, 0)
# child 3
# child 1
# Closed: 372   Open:372
# 	DOING (4, 2)
# child 6
# child 4
# child 3
# Closed: 374   Open:374
# Not for times straight please!!
# 	DOING (5, 1)
# child 1
# child 3
# Closed: 375   Open:375
# Not for times straight please!!
# 	DOING (3, 3)
# child 5
# child 6
# Closed: 376   Open:376
# 	DOING (2, 2)
# child 5
# Pos: (2, 3) f:209 g:28 h:181  Pos: (2, 3) f:206 g:25 h:181
# child 1
# child 4
# Pos: (3, 2) f:206 g:25 h:181  Pos: (3, 2) f:205 g:24 h:181
# Closed: 378   Open:378
# 	DOING (4, 2)
# child 5
# child 6
# Pos: (4, 3) f:174 g:29 h:145  Pos: (4, 3) f:172 g:27 h:145
# child 3
# Closed: 380   Open:380
# 	DOING (2, 0)
# child 3
# child 3
# Pos: (3, 0) f:249 g:24 h:225  Pos: (3, 0) f:246 g:21 h:225
# Closed: 381   Open:381
# 	DOING (2, 2)
# child 5
# child 1
# child 4
# Closed: 383   Open:383
# 	DOING (1, 1)
# child 3
# Pos: (1, 0) f:286 g:21 h:265  Pos: (1, 0) f:285 g:20 h:265
# Pos: (1, 0) f:286 g:21 h:265  Pos: (1, 0) f:285 g:20 h:265
# child 1
# Pos: (1, 2) f:242 g:21 h:221  Pos: (1, 2) f:239 g:18 h:221
# Pos: (1, 2) f:242 g:21 h:221  Pos: (1, 2) f:239 g:18 h:221
# Pos: (1, 2) f:242 g:21 h:221  Pos: (1, 2) f:239 g:18 h:221
# child 4
# Closed: 385   Open:385
# 	DOING (4, 0)
# child 3
# child 1
# Closed: 386   Open:386
# 	DOING (4, 2)
# child 6
# child 4
# child 3
# Closed: 388   Open:388
# 	DOING (5, 1)
# child 1
# child 3
# child 4
# Closed: 390   Open:390
# Not for times straight please!!
# 	DOING (0, 5)
# child 5
# Closed: 390   Open:390
# 	DOING (2, 5)
# child 5
# child 5
# child 8
# Closed: 392   Open:392
# Not for times straight please!!
# 	DOING (0, 5)
# child 5
# Pos: (1, 5) f:196 g:26 h:170  Pos: (1, 5) f:192 g:22 h:170
# Closed: 392   Open:392
# 	DOING (1, 4)
# child 5
# child 5
# child 2
# Closed: 394   Open:394
# 	DOING (2, 3)
# child 5
# child 2
# child 6
# Closed: 396   Open:396
# 	DOING (2, 5)
# child 5
# child 5
# child 8
# Closed: 398   Open:398
# 	DOING (3, 4)
# child 6
# child 8
# child 6
# Closed: 400   Open:400
# Not for times straight please!!
# 	DOING (0, 5)
# child 5
# Pos: (1, 5) f:193 g:23 h:170  Pos: (1, 5) f:192 g:22 h:170
# Pos: (1, 5) f:196 g:26 h:170  Pos: (1, 5) f:192 g:22 h:170
# Closed: 400   Open:400
# 	DOING (1, 4)
# child 5
# child 5
# child 2
# Pos: (2, 4) f:186 g:22 h:164  Pos: (2, 4) f:184 g:20 h:164
# Closed: 402   Open:402
# 	DOING (1, 2)
# child 5
# Pos: (1, 3) f:225 g:23 h:202  Pos: (1, 3) f:221 g:19 h:202
# Pos: (1, 3) f:225 g:23 h:202  Pos: (1, 3) f:221 g:19 h:202
# child 1
# child 5
# Pos: (2, 2) f:225 g:25 h:200  Pos: (2, 2) f:219 g:19 h:200
# Closed: 404   Open:404
# 	DOING (1, 4)
# child 5
# child 5
# child 2
# Closed: 406   Open:406
# 	DOING (2, 3)
# child 5
# child 2
# child 6
# Pos: (3, 3) f:190 g:28 h:162  Pos: (3, 3) f:188 g:26 h:162
# Closed: 408   Open:408
# 	DOING (2, 3)
# child 2
# child 5
# child 6
# Closed: 410   Open:410
# 	DOING (1, 2)
# child 5
# Pos: (1, 3) f:225 g:23 h:202  Pos: (1, 3) f:221 g:19 h:202
# Pos: (1, 3) f:227 g:25 h:202  Pos: (1, 3) f:221 g:19 h:202
# child 1
# child 5
# Pos: (2, 2) f:225 g:25 h:200  Pos: (2, 2) f:219 g:19 h:200
# Closed: 412   Open:412
# 	DOING (3, 2)
# child 6
# Pos: (3, 3) f:188 g:26 h:162  Pos: (3, 3) f:186 g:24 h:162
# Pos: (3, 3) f:188 g:26 h:162  Pos: (3, 3) f:186 g:24 h:162
# Pos: (3, 3) f:188 g:26 h:162  Pos: (3, 3) f:186 g:24 h:162
# Pos: (3, 3) f:188 g:26 h:162  Pos: (3, 3) f:186 g:24 h:162
# child 5
# child 4
# Closed: 414   Open:414
# 	DOING (2, 3)
# child 2
# child 5
# child 6
# Closed: 416   Open:416
# 	DOING (2, 5)
# child 5
# child 5
# child 8
# Pos: (3, 5) f:160 g:30 h:130  Pos: (3, 5) f:159 g:29 h:130
# Closed: 418   Open:418
# 	DOING (3, 4)
# child 6
# child 8
# child 6
# Closed: 420   Open:420
# 	DOING (3, 4)
# child 6
# child 8
# child 6
# Closed: 422   Open:422
# 	DOING (2, 3)
# child 2
# child 5
# child 6
# Pos: (3, 3) f:190 g:28 h:162  Pos: (3, 3) f:188 g:26 h:162
# Pos: (3, 3) f:190 g:28 h:162  Pos: (3, 3) f:188 g:26 h:162
# Closed: 424   Open:424
# 	DOING (4, 3)
# child 6
# child 6
# child 8
# Closed: 426   Open:426
# 	DOING (0, 1)
# child 2
# child 2
# Closed: 427   Open:427
# 	DOING (1, 0)
# child 2
# child 2
# Closed: 428   Open:428
# 	DOING (3, 0)
# child 4
# child 4
# Closed: 429   Open:429
# 	DOING (1, 0)
# child 2
# child 3
# Closed: 430   Open:430
# 	DOING (1, 0)
# child 2
# child 3
# Closed: 431   Open:431
# 	DOING (1, 2)
# child 5
# Pos: (1, 3) f:227 g:25 h:202  Pos: (1, 3) f:221 g:19 h:202
# Pos: (1, 3) f:227 g:25 h:202  Pos: (1, 3) f:221 g:19 h:202
# child 1
# child 5
# Pos: (2, 2) f:223 g:23 h:200  Pos: (2, 2) f:219 g:19 h:200
# Closed: 433   Open:433
# 	DOING (2, 1)
# child 3
# Pos: (2, 0) f:263 g:19 h:244  Pos: (2, 0) f:262 g:18 h:244
# Pos: (2, 0) f:263 g:19 h:244  Pos: (2, 0) f:262 g:18 h:244
# child 5
# child 4
# Pos: (3, 1) f:222 g:20 h:202  Pos: (3, 1) f:221 g:19 h:202
# Closed: 435   Open:435
# 	DOING (1, 0)
# child 2
# child 2
# Closed: 436   Open:436
# 	DOING (3, 0)
# child 4
# child 4
# Closed: 437   Open:437
# 	DOING (2, 3)
# child 2
# child 5
# child 6
# Pos: (3, 3) f:193 g:31 h:162  Pos: (3, 3) f:188 g:26 h:162
# Closed: 439   Open:439
# 	DOING (1, 2)
# child 5
# Pos: (1, 3) f:227 g:25 h:202  Pos: (1, 3) f:221 g:19 h:202
# child 1
# child 5
# Pos: (2, 2) f:220 g:20 h:200  Pos: (2, 2) f:219 g:19 h:200
# Closed: 441   Open:441
# 	DOING (3, 2)
# child 6
# Pos: (3, 3) f:188 g:26 h:162  Pos: (3, 3) f:186 g:24 h:162
# Pos: (3, 3) f:188 g:26 h:162  Pos: (3, 3) f:186 g:24 h:162
# Pos: (3, 3) f:188 g:26 h:162  Pos: (3, 3) f:186 g:24 h:162
# Pos: (3, 3) f:188 g:26 h:162  Pos: (3, 3) f:186 g:24 h:162
# Pos: (3, 3) f:188 g:26 h:162  Pos: (3, 3) f:186 g:24 h:162
# Pos: (3, 3) f:188 g:26 h:162  Pos: (3, 3) f:186 g:24 h:162
# child 5
# child 4
# Closed: 443   Open:443
# 	DOING (3, 0)
# child 3
# child 4
# Closed: 444   Open:444
# 	DOING (3, 2)
# child 6
# child 5
# child 4
# Closed: 446   Open:446
# Not for times straight please!!
# 	DOING (4, 1)
# child 4
# child 4
# Closed: 447   Open:447
# Not for times straight please!!
# 	DOING (0, 5)
# child 5
# Pos: (1, 5) f:193 g:23 h:170  Pos: (1, 5) f:192 g:22 h:170
# Pos: (1, 5) f:193 g:23 h:170  Pos: (1, 5) f:192 g:22 h:170
# Pos: (1, 5) f:196 g:26 h:170  Pos: (1, 5) f:192 g:22 h:170
# Closed: 447   Open:447
# 	DOING (2, 5)
# child 5
# child 5
# child 8
# Pos: (3, 5) f:160 g:30 h:130  Pos: (3, 5) f:159 g:29 h:130
# Pos: (3, 5) f:160 g:30 h:130  Pos: (3, 5) f:159 g:29 h:130
# Closed: 449   Open:449
# Not for times straight please!!
# 	DOING (0, 5)
# child 5
# Pos: (1, 5) f:196 g:26 h:170  Pos: (1, 5) f:192 g:22 h:170
# Closed: 449   Open:449
# 	DOING (1, 4)
# child 5
# child 5
# child 2
# Pos: (2, 4) f:186 g:22 h:164  Pos: (2, 4) f:184 g:20 h:164
# Pos: (2, 4) f:186 g:22 h:164  Pos: (2, 4) f:184 g:20 h:164
# Pos: (2, 4) f:186 g:22 h:164  Pos: (2, 4) f:184 g:20 h:164
# Pos: (2, 4) f:186 g:22 h:164  Pos: (2, 4) f:184 g:20 h:164
# Pos: (2, 4) f:186 g:22 h:164  Pos: (2, 4) f:184 g:20 h:164
# Closed: 451   Open:451
# 	DOING (2, 3)
# child 5
# child 2
# child 6
# Closed: 453   Open:453
# 	DOING (2, 5)
# child 5
# child 5
# child 8
# Closed: 455   Open:455
# 	DOING (3, 4)
# child 6
# child 8
# child 6
# Pos: (4, 4) f:159 g:31 h:128  Pos: (4, 4) f:156 g:28 h:128
# Closed: 457   Open:457
# Not for times straight please!!
# 	DOING (0, 5)
# child 5
# Pos: (1, 5) f:193 g:23 h:170  Pos: (1, 5) f:192 g:22 h:170
# Pos: (1, 5) f:196 g:26 h:170  Pos: (1, 5) f:192 g:22 h:170
# Closed: 457   Open:457
# 	DOING (1, 4)
# child 5
# child 5
# child 2
# Pos: (2, 4) f:186 g:22 h:164  Pos: (2, 4) f:184 g:20 h:164
# Closed: 459   Open:459
# 	DOING (1, 2)
# child 5
# Pos: (1, 3) f:225 g:23 h:202  Pos: (1, 3) f:221 g:19 h:202
# Pos: (1, 3) f:225 g:23 h:202  Pos: (1, 3) f:221 g:19 h:202
# child 1
# child 5
# Pos: (2, 2) f:223 g:23 h:200  Pos: (2, 2) f:219 g:19 h:200
# Pos: (2, 2) f:223 g:23 h:200  Pos: (2, 2) f:219 g:19 h:200
# Pos: (2, 2) f:225 g:25 h:200  Pos: (2, 2) f:219 g:19 h:200
# Closed: 461   Open:461
# 	DOING (1, 4)
# child 5
# child 5
# child 2
# Closed: 463   Open:463
# 	DOING (2, 3)
# child 5
# child 2
# child 6
# Pos: (3, 3) f:190 g:28 h:162  Pos: (3, 3) f:188 g:26 h:162
# Closed: 465   Open:465
# 	DOING (2, 1)
# child 3
# Pos: (2, 0) f:264 g:20 h:244  Pos: (2, 0) f:262 g:18 h:244
# child 5
# Pos: (2, 2) f:225 g:25 h:200  Pos: (2, 2) f:220 g:20 h:200
# child 4
# Pos: (3, 1) f:222 g:20 h:202  Pos: (3, 1) f:221 g:19 h:202
# Closed: 467   Open:467
# 	DOING (2, 3)
# child 5
# child 2
# child 6
# Closed: 469   Open:469
# Not for times straight please!!
# 	DOING (3, 2)
# child 4
# child 6
# Closed: 470   Open:470
# 	DOING (2, 5)
# child 5
# child 5
# child 8
# Closed: 472   Open:472
# 	DOING (1, 4)
# child 5
# child 5
# Pos: (1, 5) f:197 g:27 h:170  Pos: (1, 5) f:193 g:23 h:170
# child 2
# Pos: (2, 4) f:186 g:22 h:164  Pos: (2, 4) f:184 g:20 h:164
# Pos: (2, 4) f:186 g:22 h:164  Pos: (2, 4) f:184 g:20 h:164
# Closed: 474   Open:474
# 	DOING (3, 4)
# child 6
# child 8
# child 6
# Closed: 476   Open:476
# 	DOING (3, 4)
# child 6
# child 8
# child 6
# Closed: 478   Open:478
# 	DOING (2, 3)
# child 5
# child 2
# child 6
# Pos: (3, 3) f:191 g:29 h:162  Pos: (3, 3) f:188 g:26 h:162
# Pos: (3, 3) f:191 g:29 h:162  Pos: (3, 3) f:188 g:26 h:162
# Closed: 480   Open:480
# 	DOING (4, 3)
# child 6
# child 6
# child 8
# Closed: 482   Open:482
# 	DOING (1, 0)
# child 2
# child 3
# Closed: 483   Open:483
# 	DOING (3, 0)
# child 4
# Pos: (3, 1) f:226 g:24 h:202  Pos: (3, 1) f:225 g:23 h:202
# child 4
# Closed: 484   Open:484
# 	DOING (1, 0)
# child 2
# child 3
# Closed: 485   Open:485
# 	DOING (1, 2)
# child 5
# Pos: (1, 3) f:225 g:23 h:202  Pos: (1, 3) f:221 g:19 h:202
# Pos: (1, 3) f:225 g:23 h:202  Pos: (1, 3) f:221 g:19 h:202
# child 1
# child 5
# Pos: (2, 2) f:220 g:20 h:200  Pos: (2, 2) f:219 g:19 h:200
# Pos: (2, 2) f:220 g:20 h:200  Pos: (2, 2) f:219 g:19 h:200
# Pos: (2, 2) f:225 g:25 h:200  Pos: (2, 2) f:219 g:19 h:200
# Pos: (2, 2) f:225 g:25 h:200  Pos: (2, 2) f:219 g:19 h:200
# Closed: 487   Open:487
# 	DOING (2, 1)
# child 3
# Pos: (2, 0) f:263 g:19 h:244  Pos: (2, 0) f:262 g:18 h:244
# Pos: (2, 0) f:263 g:19 h:244  Pos: (2, 0) f:262 g:18 h:244
# child 5
# child 4
# Pos: (3, 1) f:225 g:23 h:202  Pos: (3, 1) f:221 g:19 h:202
# Pos: (3, 1) f:225 g:23 h:202  Pos: (3, 1) f:221 g:19 h:202
# Closed: 489   Open:489
# 	DOING (3, 0)
# child 4
# child 4
# Closed: 490   Open:490
# Not for times straight please!!
# 	DOING (3, 2)
# child 4
# child 6
# Pos: (3, 3) f:193 g:31 h:162  Pos: (3, 3) f:188 g:26 h:162
# Closed: 491   Open:491
# 	DOING (4, 1)
# child 4
# child 4
# child 4
# Closed: 493   Open:493
# Not for times straight please!!
# 	DOING (2, 5)
# child 5
# child 8
# Pos: (3, 5) f:161 g:31 h:130  Pos: (3, 5) f:160 g:30 h:130
# Pos: (3, 5) f:161 g:31 h:130  Pos: (3, 5) f:160 g:30 h:130
# Closed: 494   Open:494
# 	DOING (1, 4)
# child 5
# child 5
# Pos: (1, 5) f:197 g:27 h:170  Pos: (1, 5) f:193 g:23 h:170
# child 2
# Pos: (2, 4) f:186 g:22 h:164  Pos: (2, 4) f:184 g:20 h:164
# Closed: 496   Open:496
# 	DOING (3, 4)
# child 6
# child 8
# child 6
# Pos: (4, 4) f:159 g:31 h:128  Pos: (4, 4) f:157 g:29 h:128
# Closed: 498   Open:498
# 	DOING (1, 2)
# child 5
# Pos: (1, 3) f:225 g:23 h:202  Pos: (1, 3) f:221 g:19 h:202
# child 1
# child 5
# Pos: (2, 2) f:220 g:20 h:200  Pos: (2, 2) f:219 g:19 h:200
# Closed: 500   Open:500
# 	DOING (1, 4)
# child 5
# child 5
# child 2
# Closed: 502   Open:502
# 	DOING (2, 3)
# child 5
# child 2
# child 6
# Pos: (3, 3) f:191 g:29 h:162  Pos: (3, 3) f:188 g:26 h:162
# Closed: 504   Open:504
# 	DOING (3, 4)
# child 6
# child 8
# child 6
# Closed: 506   Open:506
# 	DOING (2, 3)
# child 5
# child 2
# child 6
# Pos: (3, 3) f:191 g:29 h:162  Pos: (3, 3) f:188 g:26 h:162
# Closed: 508   Open:508
# 	DOING (4, 3)
# child 6
# child 6
# child 8
# Closed: 510   Open:510
# 	DOING (3, 0)
# child 4
# Pos: (3, 1) f:226 g:24 h:202  Pos: (3, 1) f:225 g:23 h:202
# child 4
# Pos: (4, 0) f:234 g:26 h:208  Pos: (4, 0) f:231 g:23 h:208
# Closed: 511   Open:511
# Not for times straight please!!
# 	DOING (3, 2)
# child 4
# child 6
# Pos: (3, 3) f:193 g:31 h:162  Pos: (3, 3) f:188 g:26 h:162
# Closed: 512   Open:512
# 	DOING (4, 1)
# child 4
# child 4
# child 4
# Closed: 514   Open:514
# 	DOING (3, 4)
# child 6
# child 8
# child 6
# Pos: (4, 4) f:159 g:31 h:128  Pos: (4, 4) f:157 g:29 h:128
# Closed: 516   Open:516
# 	DOING (2, 3)
# child 5
# child 2
# child 6
# Pos: (3, 3) f:191 g:29 h:162  Pos: (3, 3) f:188 g:26 h:162
# Closed: 518   Open:518
# 	DOING (4, 3)
# child 6
# child 6
# child 8
# Closed: 520   Open:520
# Not for times straight please!!
# 	DOING (0, 5)
# child 5
# Pos: (1, 5) f:193 g:23 h:170  Pos: (1, 5) f:192 g:22 h:170
# Pos: (1, 5) f:193 g:23 h:170  Pos: (1, 5) f:192 g:22 h:170
# Pos: (1, 5) f:193 g:23 h:170  Pos: (1, 5) f:192 g:22 h:170
# Pos: (1, 5) f:193 g:23 h:170  Pos: (1, 5) f:192 g:22 h:170
# Pos: (1, 5) f:193 g:23 h:170  Pos: (1, 5) f:192 g:22 h:170
# Pos: (1, 5) f:193 g:23 h:170  Pos: (1, 5) f:192 g:22 h:170
# Pos: (1, 5) f:193 g:23 h:170  Pos: (1, 5) f:192 g:22 h:170
# Closed: 520   Open:520
# 	DOING (1, 4)
# child 5
# child 5
# child 2
# Pos: (2, 4) f:186 g:22 h:164  Pos: (2, 4) f:184 g:20 h:164
# Pos: (2, 4) f:186 g:22 h:164  Pos: (2, 4) f:184 g:20 h:164
# Pos: (2, 4) f:186 g:22 h:164  Pos: (2, 4) f:184 g:20 h:164
# Closed: 522   Open:522
# 	DOING (1, 2)
# child 5
# Pos: (1, 3) f:225 g:23 h:202  Pos: (1, 3) f:221 g:19 h:202
# Pos: (1, 3) f:225 g:23 h:202  Pos: (1, 3) f:221 g:19 h:202
# child 1
# child 5
# Pos: (2, 2) f:225 g:25 h:200  Pos: (2, 2) f:219 g:19 h:200
# Pos: (2, 2) f:225 g:25 h:200  Pos: (2, 2) f:219 g:19 h:200
# Pos: (2, 2) f:225 g:25 h:200  Pos: (2, 2) f:219 g:19 h:200
# Closed: 524   Open:524
# 	DOING (1, 4)
# child 5
# child 5
# child 2
# Closed: 526   Open:526
# 	DOING (2, 3)
# child 5
# child 2
# child 6
# Pos: (3, 3) f:193 g:31 h:162  Pos: (3, 3) f:188 g:26 h:162
# Closed: 528   Open:528
# 	DOING (2, 1)
# child 3
# child 5
# Pos: (2, 2) f:225 g:25 h:200  Pos: (2, 2) f:220 g:20 h:200
# child 4
# Pos: (3, 1) f:225 g:23 h:202  Pos: (3, 1) f:221 g:19 h:202
# Pos: (3, 1) f:225 g:23 h:202  Pos: (3, 1) f:221 g:19 h:202
# Pos: (3, 1) f:225 g:23 h:202  Pos: (3, 1) f:221 g:19 h:202
# Pos: (3, 1) f:226 g:24 h:202  Pos: (3, 1) f:221 g:19 h:202
# Closed: 530   Open:530
# 	DOING (2, 3)
# child 5
# child 2
# child 6
# Closed: 532   Open:532
# Not for times straight please!!
# 	DOING (3, 2)
# child 4
# child 6
# Closed: 533   Open:533
# 	DOING (2, 5)
# child 5
# child 5
# child 8
# Pos: (3, 5) f:161 g:31 h:130  Pos: (3, 5) f:160 g:30 h:130
# Pos: (3, 5) f:161 g:31 h:130  Pos: (3, 5) f:160 g:30 h:130
# Pos: (3, 5) f:161 g:31 h:130  Pos: (3, 5) f:160 g:30 h:130
# Closed: 535   Open:535
# 	DOING (1, 4)
# child 5
# child 5
# Pos: (1, 5) f:197 g:27 h:170  Pos: (1, 5) f:193 g:23 h:170
# child 2
# Pos: (2, 4) f:186 g:22 h:164  Pos: (2, 4) f:184 g:20 h:164
# Pos: (2, 4) f:186 g:22 h:164  Pos: (2, 4) f:184 g:20 h:164
# Closed: 537   Open:537
# 	DOING (3, 4)
# child 6
# child 8
# child 6
# Pos: (4, 4) f:159 g:31 h:128  Pos: (4, 4) f:157 g:29 h:128
# Closed: 539   Open:539
# 	DOING (3, 4)
# child 6
# child 8
# child 6
# Closed: 541   Open:541
# 	DOING (2, 3)
# child 5
# child 2
# child 6
# Pos: (3, 3) f:191 g:29 h:162  Pos: (3, 3) f:188 g:26 h:162
# Pos: (3, 3) f:191 g:29 h:162  Pos: (3, 3) f:188 g:26 h:162
# Closed: 543   Open:543
# 	DOING (4, 3)
# child 6
# child 6
# child 8
# Closed: 545   Open:545
# 	DOING (1, 0)
# child 2
# child 3
# Closed: 546   Open:546
# 	DOING (1, 0)
# child 2
# child 3
# Closed: 547   Open:547
# 	DOING (1, 2)
# child 5
# Pos: (1, 3) f:225 g:23 h:202  Pos: (1, 3) f:221 g:19 h:202
# Pos: (1, 3) f:225 g:23 h:202  Pos: (1, 3) f:221 g:19 h:202
# child 1
# child 5
# Pos: (2, 2) f:220 g:20 h:200  Pos: (2, 2) f:219 g:19 h:200
# Pos: (2, 2) f:220 g:20 h:200  Pos: (2, 2) f:219 g:19 h:200
# Pos: (2, 2) f:225 g:25 h:200  Pos: (2, 2) f:219 g:19 h:200
# Pos: (2, 2) f:225 g:25 h:200  Pos: (2, 2) f:219 g:19 h:200
# Closed: 549   Open:549
# 	DOING (2, 1)
# child 3
# Pos: (2, 0) f:263 g:19 h:244  Pos: (2, 0) f:262 g:18 h:244
# Pos: (2, 0) f:263 g:19 h:244  Pos: (2, 0) f:262 g:18 h:244
# child 5
# child 4
# Pos: (3, 1) f:226 g:24 h:202  Pos: (3, 1) f:221 g:19 h:202
# Closed: 551   Open:551
# Not for times straight please!!
# 	DOING (0, 5)
# child 5
# Pos: (1, 5) f:193 g:23 h:170  Pos: (1, 5) f:192 g:22 h:170
# Pos: (1, 5) f:193 g:23 h:170  Pos: (1, 5) f:192 g:22 h:170
# Pos: (1, 5) f:193 g:23 h:170  Pos: (1, 5) f:192 g:22 h:170
# Pos: (1, 5) f:193 g:23 h:170  Pos: (1, 5) f:192 g:22 h:170
# Closed: 551   Open:551
# 	DOING (1, 4)
# child 5
# child 5
# child 2
# Pos: (2, 4) f:186 g:22 h:164  Pos: (2, 4) f:184 g:20 h:164
# Closed: 553   Open:553
# 	DOING (1, 2)
# child 5
# Pos: (1, 3) f:225 g:23 h:202  Pos: (1, 3) f:221 g:19 h:202
# child 1
# child 5
# Pos: (2, 2) f:220 g:20 h:200  Pos: (2, 2) f:219 g:19 h:200
# Closed: 555   Open:555
# 	DOING (1, 4)
# child 5
# child 5
# child 2
# Closed: 557   Open:557
# 	DOING (2, 3)
# child 5
# child 2
# child 6
# Pos: (3, 3) f:193 g:31 h:162  Pos: (3, 3) f:188 g:26 h:162
# Closed: 559   Open:559
# 	DOING (1, 0)
# child 2
# child 3
# Closed: 560   Open:560
# 	DOING (3, 0)
# child 4
# child 4
# Pos: (4, 0) f:234 g:26 h:208  Pos: (4, 0) f:231 g:23 h:208
# Closed: 561   Open:561
# 	DOING (1, 0)
# child 2
# child 3
# Closed: 562   Open:562
# 	DOING (1, 2)
# child 5
# Pos: (1, 3) f:225 g:23 h:202  Pos: (1, 3) f:221 g:19 h:202
# child 1
# child 5
# Pos: (2, 2) f:225 g:25 h:200  Pos: (2, 2) f:219 g:19 h:200
# Closed: 564   Open:564
# 	DOING (2, 1)
# child 3
# Pos: (2, 0) f:263 g:19 h:244  Pos: (2, 0) f:262 g:18 h:244
# Pos: (2, 0) f:263 g:19 h:244  Pos: (2, 0) f:262 g:18 h:244
# child 5
# child 4
# Pos: (3, 1) f:225 g:23 h:202  Pos: (3, 1) f:221 g:19 h:202
# Closed: 566   Open:566
# 	DOING (3, 0)
# child 4
# child 4
# Closed: 567   Open:567
# Not for times straight please!!
# 	DOING (3, 2)
# child 4
# child 6
# Closed: 568   Open:568
# 	DOING (4, 1)
# child 4
# child 4
# child 4
# Closed: 570   Open:570
# Not for times straight please!!
# 	DOING (2, 5)
# child 5
# child 8
# Pos: (3, 5) f:161 g:31 h:130  Pos: (3, 5) f:160 g:30 h:130
# Pos: (3, 5) f:161 g:31 h:130  Pos: (3, 5) f:160 g:30 h:130
# Closed: 571   Open:571
# 	DOING (1, 4)
# child 5
# child 5
# Pos: (1, 5) f:197 g:27 h:170  Pos: (1, 5) f:193 g:23 h:170
# child 2
# Pos: (2, 4) f:186 g:22 h:164  Pos: (2, 4) f:184 g:20 h:164
# Closed: 573   Open:573
# 	DOING (3, 4)
# child 6
# child 8
# child 6
# Pos: (4, 4) f:159 g:31 h:128  Pos: (4, 4) f:157 g:29 h:128
# Closed: 575   Open:575
# 	DOING (1, 2)
# child 5
# Pos: (1, 3) f:225 g:23 h:202  Pos: (1, 3) f:221 g:19 h:202
# child 1
# child 5
# Pos: (2, 2) f:220 g:20 h:200  Pos: (2, 2) f:219 g:19 h:200
# Closed: 577   Open:577
# 	DOING (1, 4)
# child 5
# child 5
# child 2
# Closed: 579   Open:579
# 	DOING (2, 3)
# child 5
# child 2
# child 6
# Pos: (3, 3) f:191 g:29 h:162  Pos: (3, 3) f:188 g:26 h:162
# Closed: 581   Open:581
# 	DOING (3, 4)
# child 6
# child 8
# child 6
# Closed: 583   Open:583
# 	DOING (2, 3)
# child 5
# child 2
# child 6
# Pos: (3, 3) f:191 g:29 h:162  Pos: (3, 3) f:188 g:26 h:162
# Closed: 585   Open:585
# 	DOING (4, 3)
# child 6
# child 6
# child 8
# Closed: 587   Open:587
# Not for times straight please!!
# 	DOING (3, 2)
# child 4
# child 6
# Pos: (3, 3) f:193 g:31 h:162  Pos: (3, 3) f:188 g:26 h:162
# Closed: 588   Open:588
# 	DOING (2, 1)
# child 3
# child 5
# Pos: (2, 2) f:225 g:25 h:200  Pos: (2, 2) f:220 g:20 h:200
# Pos: (2, 2) f:225 g:25 h:200  Pos: (2, 2) f:220 g:20 h:200
# child 4
# Pos: (3, 1) f:225 g:23 h:202  Pos: (3, 1) f:221 g:19 h:202
# Pos: (3, 1) f:226 g:24 h:202  Pos: (3, 1) f:221 g:19 h:202
# Pos: (3, 1) f:226 g:24 h:202  Pos: (3, 1) f:221 g:19 h:202
# Closed: 590   Open:590
# 	DOING (4, 1)
# child 4
# child 4
# child 4
# Closed: 592   Open:592
# 	DOING (3, 4)
# child 6
# child 8
# child 6
# Pos: (4, 4) f:159 g:31 h:128  Pos: (4, 4) f:157 g:29 h:128
# Closed: 594   Open:594
# 	DOING (2, 3)
# child 5
# child 2
# child 6
# Pos: (3, 3) f:191 g:29 h:162  Pos: (3, 3) f:188 g:26 h:162
# Closed: 596   Open:596
# 	DOING (4, 3)
# child 6
# child 6
# child 8
# Closed: 598   Open:598
# 	DOING (4, 1)
# child 4
# child 4
# child 4
# Closed: 600   Open:600
# 	DOING (4, 3)
# child 6
# child 6
# child 8
# Closed: 602   Open:602
# 	DOING (1, 0)
# child 2
# child 3
# Closed: 603   Open:603
# 	DOING (1, 2)
# child 5
# Pos: (1, 3) f:225 g:23 h:202  Pos: (1, 3) f:221 g:19 h:202
# child 1
# child 5
# Pos: (2, 2) f:220 g:20 h:200  Pos: (2, 2) f:219 g:19 h:200
# Pos: (2, 2) f:220 g:20 h:200  Pos: (2, 2) f:219 g:19 h:200
# Pos: (2, 2) f:220 g:20 h:200  Pos: (2, 2) f:219 g:19 h:200
# Pos: (2, 2) f:225 g:25 h:200  Pos: (2, 2) f:219 g:19 h:200
# Closed: 605   Open:605
# 	DOING (2, 1)
# child 3
# Pos: (2, 0) f:263 g:19 h:244  Pos: (2, 0) f:262 g:18 h:244
# child 5
# child 4
# Closed: 607   Open:607
# 	DOING (1, 0)
# child 2
# child 3
# Closed: 608   Open:608
# 	DOING (1, 0)
# child 2
# child 3
# Closed: 609   Open:609
# 	DOING (1, 0)
# child 2
# child 3
# Closed: 610   Open:610
# 	DOING (1, 2)
# child 5
# child 1
# child 5
# Pos: (2, 2) f:220 g:20 h:200  Pos: (2, 2) f:219 g:19 h:200
# Closed: 612   Open:612
# 	DOING (2, 1)
# child 3
# Pos: (2, 0) f:263 g:19 h:244  Pos: (2, 0) f:262 g:18 h:244
# Pos: (2, 0) f:263 g:19 h:244  Pos: (2, 0) f:262 g:18 h:244
# Pos: (2, 0) f:263 g:19 h:244  Pos: (2, 0) f:262 g:18 h:244
# child 5
# child 4
# Closed: 614   Open:614
# Not for times straight please!!
# 	DOING (0, 5)
# child 5
# Pos: (1, 5) f:193 g:23 h:170  Pos: (1, 5) f:192 g:22 h:170
# Pos: (1, 5) f:193 g:23 h:170  Pos: (1, 5) f:192 g:22 h:170
# Pos: (1, 5) f:193 g:23 h:170  Pos: (1, 5) f:192 g:22 h:170
# Pos: (1, 5) f:193 g:23 h:170  Pos: (1, 5) f:192 g:22 h:170
# Pos: (1, 5) f:193 g:23 h:170  Pos: (1, 5) f:192 g:22 h:170
# Closed: 614   Open:614
# 	DOING (1, 4)
# child 5
# child 5
# child 2
# Pos: (2, 4) f:186 g:22 h:164  Pos: (2, 4) f:184 g:20 h:164
# ...
# child 5
# Pos: (5, 4) f:148 g:35 h:113  Pos: (5, 4) f:147 g:34 h:113
# Closed: 1709   Open:1709
# 	DOING (1, 3)
# child 4
# Pos: (1, 4) f:211 g:26 h:185  Pos: (1, 4) f:208 g:23 h:185
# child 3
# child 5
# Pos: (2, 3) f:206 g:25 h:181  Pos: (2, 3) f:205 g:24 h:181
# Closed: 1711   Open:1711
# 	DOING (0, 2)
# child 4
# child 3
# Pos: (0, 3) f:247 g:22 h:225  Pos: (0, 3) f:243 g:18 h:225
# Pos: (0, 3) f:247 g:22 h:225  Pos: (0, 3) f:243 g:18 h:225
# Closed: 1712   Open:1712
# 	DOING (2, 2)
# child 2
# child 5
# child 4
# Pos: (3, 2) f:211 g:30 h:181  Pos: (3, 2) f:204 g:23 h:181
# Closed: 1714   Open:1714
# 	DOING (1, 3)
# child 4
# child 3
# child 5
# Closed: 1716   Open:1716
# 	DOING (1, 5)
# child 4
# child 3
# child 4
# Closed: 1718   Open:1718
# 	DOING (2, 4)
# child 5
# child 4
# Pos: (2, 5) f:175 g:26 h:149  Pos: (2, 5) f:173 g:24 h:149
# child 5
# Pos: (3, 4) f:176 g:31 h:145  Pos: (3, 4) f:170 g:25 h:145
# Pos: (3, 4) f:180 g:35 h:145  Pos: (3, 4) f:170 g:25 h:145
# Closed: 1720   Open:1720
# 	DOING (2, 2)
# child 2
# child 5
# Pos: (2, 3) f:206 g:25 h:181  Pos: (2, 3) f:205 g:24 h:181
# child 4
# Closed: 1722   Open:1722
# 	DOING (2, 4)
# child 5
# child 4
# child 5
# Closed: 1724   Open:1724
# Not for times straight please!!
# 	DOING (3, 3)
# child 4
# child 5
# Closed: 1725   Open:1725
# Not for times straight please!!
# 	DOING (3, 3)
# child 4
# child 5
# Closed: 1726   Open:1726
# 	DOING (3, 5)
# child 5
# child 5
# child 5
# Closed: 1728   Open:1728
# 	DOING (4, 4)
# child 6
# child 5
# Pos: (4, 5) f:148 g:35 h:113  Pos: (4, 5) f:147 g:34 h:113
# child 5
# Closed: 1730   Open:1730
# 	DOING (2, 2)
# child 2
# child 5
# Pos: (2, 3) f:206 g:25 h:181  Pos: (2, 3) f:205 g:24 h:181
# child 4
# Pos: (3, 2) f:211 g:30 h:181  Pos: (3, 2) f:204 g:23 h:181
# Pos: (3, 2) f:211 g:30 h:181  Pos: (3, 2) f:204 g:23 h:181
# Closed: 1732   Open:1732
# 	DOING (2, 4)
# child 5
# child 4
# child 5
# Pos: (3, 4) f:176 g:31 h:145  Pos: (3, 4) f:170 g:25 h:145
# Pos: (3, 4) f:176 g:31 h:145  Pos: (3, 4) f:170 g:25 h:145
# Pos: (3, 4) f:180 g:35 h:145  Pos: (3, 4) f:170 g:25 h:145
# Closed: 1734   Open:1734
# Not for times straight please!!
# 	DOING (3, 3)
# child 4
# child 5
# Closed: 1735   Open:1735
# 	DOING (4, 4)
# child 6
# child 5
# child 5
# Closed: 1737   Open:1737
# 	DOING (3, 3)
# child 5
# child 5
# child 6
# Pos: (4, 3) f:180 g:35 h:145  Pos: (4, 3) f:177 g:32 h:145
# Pos: (4, 3) f:180 g:35 h:145  Pos: (4, 3) f:177 g:32 h:145
# Pos: (4, 3) f:180 g:35 h:145  Pos: (4, 3) f:177 g:32 h:145
# Closed: 1739   Open:1739
# 	DOING (5, 3)
# child 5
# child 6
# child 7
# Closed: 1741   Open:1741
# Not for times straight please!!
# 	DOING (3, 1)
# child 3
# child 4
# Pos: (3, 2) f:211 g:30 h:181  Pos: (3, 2) f:204 g:23 h:181
# Closed: 1742   Open:1742
# 	DOING (3, 3)
# child 5
# child 5
# child 6
# Pos: (4, 3) f:181 g:36 h:145  Pos: (4, 3) f:177 g:32 h:145
# Closed: 1744   Open:1744
# 	DOING (2, 0)
# child 3
# child 3
# Pos: (3, 0) f:247 g:22 h:225  Pos: (3, 0) f:246 g:21 h:225
# Pos: (3, 0) f:247 g:22 h:225  Pos: (3, 0) f:246 g:21 h:225
# Pos: (3, 0) f:247 g:22 h:225  Pos: (3, 0) f:246 g:21 h:225
# Pos: (3, 0) f:247 g:22 h:225  Pos: (3, 0) f:246 g:21 h:225
# Closed: 1745   Open:1745
# 	DOING (2, 2)
# child 2
# child 5
# Pos: (2, 3) f:206 g:25 h:181  Pos: (2, 3) f:205 g:24 h:181
# Pos: (2, 3) f:212 g:31 h:181  Pos: (2, 3) f:205 g:24 h:181
# Pos: (2, 3) f:212 g:31 h:181  Pos: (2, 3) f:205 g:24 h:181
# child 4
# Closed: 1747   Open:1747
# Not for times straight please!!
# 	DOING (3, 1)
# child 3
# child 4
# Closed: 1748   Open:1748
# 	DOING (4, 0)
# child 5
# child 1
# Closed: 1749   Open:1749
# Not for times straight please!!
# 	DOING (4, 2)
# child 5
# child 6
# Pos: (4, 3) f:177 g:32 h:145  Pos: (4, 3) f:175 g:30 h:145
# Pos: (4, 3) f:177 g:32 h:145  Pos: (4, 3) f:175 g:30 h:145
# Pos: (4, 3) f:177 g:32 h:145  Pos: (4, 3) f:175 g:30 h:145
# Pos: (4, 3) f:177 g:32 h:145  Pos: (4, 3) f:175 g:30 h:145
# Pos: (4, 3) f:177 g:32 h:145  Pos: (4, 3) f:175 g:30 h:145
# Pos: (4, 3) f:177 g:32 h:145  Pos: (4, 3) f:175 g:30 h:145
# Closed: 1750   Open:1750
# 	DOING (5, 1)
# child 3
# child 5
# Pos: (4, 1) f:213 g:28 h:185  Pos: (4, 1) f:212 g:27 h:185
# Pos: (4, 1) f:214 g:29 h:185  Pos: (4, 1) f:212 g:27 h:185
# child 4
# Closed: 1752   Open:1752
# Not for times straight please!!
# 	DOING (3, 3)
# child 4
# child 5
# Closed: 1753   Open:1753
# 	DOING (3, 5)
# child 5
# child 5
# child 5
# Closed: 1755   Open:1755
# 	DOING (4, 4)
# child 6
# child 5
# Pos: (4, 5) f:148 g:35 h:113  Pos: (4, 5) f:147 g:34 h:113
# child 5
# Pos: (5, 4) f:148 g:35 h:113  Pos: (5, 4) f:147 g:34 h:113
# Closed: 1757   Open:1757
# 	DOING (2, 2)
# child 2
# child 5
# child 4
# Pos: (3, 2) f:211 g:30 h:181  Pos: (3, 2) f:204 g:23 h:181
# Closed: 1759   Open:1759
# 	DOING (2, 4)
# child 5
# child 4
# child 5
# Pos: (3, 4) f:176 g:31 h:145  Pos: (3, 4) f:170 g:25 h:145
# Pos: (3, 4) f:176 g:31 h:145  Pos: (3, 4) f:170 g:25 h:145
# Pos: (3, 4) f:176 g:31 h:145  Pos: (3, 4) f:170 g:25 h:145
# Pos: (3, 4) f:176 g:31 h:145  Pos: (3, 4) f:170 g:25 h:145
# Pos: (3, 4) f:180 g:35 h:145  Pos: (3, 4) f:170 g:25 h:145
# Closed: 1761   Open:1761
# Not for times straight please!!
# 	DOING (3, 3)
# child 4
# child 5
# Closed: 1762   Open:1762
# 	DOING (4, 4)
# child 6
# child 5
# child 5
# Closed: 1764   Open:1764
# 	DOING (3, 3)
# child 5
# child 5
# child 6
# Pos: (4, 3) f:180 g:35 h:145  Pos: (4, 3) f:177 g:32 h:145
# Pos: (4, 3) f:180 g:35 h:145  Pos: (4, 3) f:177 g:32 h:145
# Closed: 1766   Open:1766
# 	DOING (5, 3)
# child 5
# child 6
# child 7
# Closed: 1768   Open:1768
# 	DOING (4, 0)
# child 5
# child 1
# Closed: 1769   Open:1769
# Not for times straight please!!
# 	DOING (4, 2)
# child 5
# child 6
# Pos: (4, 3) f:177 g:32 h:145  Pos: (4, 3) f:175 g:30 h:145
# Pos: (4, 3) f:177 g:32 h:145  Pos: (4, 3) f:175 g:30 h:145
# Pos: (4, 3) f:177 g:32 h:145  Pos: (4, 3) f:175 g:30 h:145
# Pos: (4, 3) f:181 g:36 h:145  Pos: (4, 3) f:175 g:30 h:145
# Closed: 1770   Open:1770
# 	DOING (5, 1)
# child 3
# child 5
# Pos: (4, 1) f:213 g:28 h:185  Pos: (4, 1) f:212 g:27 h:185
# Pos: (4, 1) f:214 g:29 h:185  Pos: (4, 1) f:212 g:27 h:185
# child 4
# Closed: 1772   Open:1772
# 	DOING (4, 4)
# child 6
# child 5
# child 5
# Pos: (5, 4) f:148 g:35 h:113  Pos: (5, 4) f:147 g:34 h:113
# Closed: 1774   Open:1774
# 	DOING (3, 3)
# child 5
# child 5
# child 6
# Pos: (4, 3) f:180 g:35 h:145  Pos: (4, 3) f:177 g:32 h:145
# Closed: 1776   Open:1776
# 	DOING (5, 3)
# child 5
# child 6
# child 7
# Closed: 1778   Open:1778
# Not for times straight please!!
# 	DOING (3, 1)
# child 3
# child 4
# Pos: (3, 2) f:211 g:30 h:181  Pos: (3, 2) f:204 g:23 h:181
# Closed: 1779   Open:1779
# 	DOING (3, 3)
# child 5
# child 5
# child 6
# Pos: (4, 3) f:181 g:36 h:145  Pos: (4, 3) f:177 g:32 h:145
# Closed: 1781   Open:1781
# 	DOING (2, 0)
# child 3
# child 3
# Pos: (3, 0) f:247 g:22 h:225  Pos: (3, 0) f:246 g:21 h:225
# Pos: (3, 0) f:247 g:22 h:225  Pos: (3, 0) f:246 g:21 h:225
# Closed: 1782   Open:1782
# 	DOING (2, 2)
# child 2
# child 5
# Pos: (2, 3) f:206 g:25 h:181  Pos: (2, 3) f:205 g:24 h:181
# Pos: (2, 3) f:212 g:31 h:181  Pos: (2, 3) f:205 g:24 h:181
# Pos: (2, 3) f:212 g:31 h:181  Pos: (2, 3) f:205 g:24 h:181
# Pos: (2, 3) f:212 g:31 h:181  Pos: (2, 3) f:205 g:24 h:181
# child 4
# Closed: 1784   Open:1784
# Not for times straight please!!
# 	DOING (3, 1)
# child 3
# child 4
# Closed: 1785   Open:1785
# 	DOING (4, 0)
# child 5
# child 1
# Closed: 1786   Open:1786
# Not for times straight please!!
# 	DOING (4, 2)
# child 5
# child 6
# Pos: (4, 3) f:177 g:32 h:145  Pos: (4, 3) f:175 g:30 h:145
# Pos: (4, 3) f:177 g:32 h:145  Pos: (4, 3) f:175 g:30 h:145
# Pos: (4, 3) f:177 g:32 h:145  Pos: (4, 3) f:175 g:30 h:145
# Pos: (4, 3) f:177 g:32 h:145  Pos: (4, 3) f:175 g:30 h:145
# Closed: 1787   Open:1787
# 	DOING (5, 1)
# child 3
# child 5
# Pos: (4, 1) f:213 g:28 h:185  Pos: (4, 1) f:212 g:27 h:185
# Pos: (4, 1) f:214 g:29 h:185  Pos: (4, 1) f:212 g:27 h:185
# child 4
# Closed: 1789   Open:1789
# Not for times straight please!!
# 	DOING (4, 2)
# child 5
# child 6
# Closed: 1790   Open:1790
# Not for times straight please!!
# 	DOING (3, 1)
# child 3
# child 4
# Closed: 1791   Open:1791
# 	DOING (5, 1)
# child 3
# child 5
# Pos: (4, 1) f:214 g:29 h:185  Pos: (4, 1) f:212 g:27 h:185
# child 4
# Closed: 1793   Open:1793
# 	DOING (5, 1)
# child 3
# child 5
# child 4
# Closed: 1795   Open:1795
# Not for times straight please!!
# 	DOING (3, 3)
# child 4
# child 5
# Closed: 1796   Open:1796
# 	DOING (3, 5)
# child 5
# child 5
# child 5
# Closed: 1798   Open:1798
# 	DOING (4, 4)
# child 6
# child 5
# Pos: (4, 5) f:148 g:35 h:113  Pos: (4, 5) f:147 g:34 h:113
# child 5
# Pos: (5, 4) f:148 g:35 h:113  Pos: (5, 4) f:147 g:34 h:113
# Closed: 1800   Open:1800
# 	DOING (2, 2)
# child 2
# child 5
# child 4
# Pos: (3, 2) f:211 g:30 h:181  Pos: (3, 2) f:204 g:23 h:181
# Closed: 1802   Open:1802
# 	DOING (2, 4)
# child 5
# child 4
# child 5
# Pos: (3, 4) f:176 g:31 h:145  Pos: (3, 4) f:170 g:25 h:145
# Pos: (3, 4) f:176 g:31 h:145  Pos: (3, 4) f:170 g:25 h:145
# Pos: (3, 4) f:176 g:31 h:145  Pos: (3, 4) f:170 g:25 h:145
# Pos: (3, 4) f:176 g:31 h:145  Pos: (3, 4) f:170 g:25 h:145
# Pos: (3, 4) f:176 g:31 h:145  Pos: (3, 4) f:170 g:25 h:145
# Pos: (3, 4) f:180 g:35 h:145  Pos: (3, 4) f:170 g:25 h:145
# Closed: 1804   Open:1804
# Not for times straight please!!
# 	DOING (3, 3)
# child 4
# child 5
# Closed: 1805   Open:1805
# 	DOING (4, 4)
# child 6
# child 5
# child 5
# Closed: 1807   Open:1807
# Not for times straight please!!
# 	DOING (3, 3)
# child 4
# child 5
# Closed: 1808   Open:1808
# 	DOING (5, 3)
# child 5
# child 6
# child 7
# Closed: 1810   Open:1810
# 	DOING (2, 0)
# child 3
# child 3
# Pos: (3, 0) f:247 g:22 h:225  Pos: (3, 0) f:246 g:21 h:225
# Pos: (3, 0) f:247 g:22 h:225  Pos: (3, 0) f:246 g:21 h:225
# Closed: 1811   Open:1811
# 	DOING (2, 2)
# child 2
# child 5
# Pos: (2, 3) f:206 g:25 h:181  Pos: (2, 3) f:205 g:24 h:181
# child 4
# Pos: (3, 2) f:211 g:30 h:181  Pos: (3, 2) f:204 g:23 h:181
# Pos: (3, 2) f:211 g:30 h:181  Pos: (3, 2) f:204 g:23 h:181
# Closed: 1813   Open:1813
# Not for times straight please!!
# 	DOING (3, 1)
# child 3
# child 4
# Closed: 1814   Open:1814
# 	DOING (2, 2)
# child 2
# child 5
# child 4
# Closed: 1816   Open:1816
# 	DOING (2, 4)
# child 5
# child 4
# child 5
# Pos: (3, 4) f:176 g:31 h:145  Pos: (3, 4) f:170 g:25 h:145
# Pos: (3, 4) f:176 g:31 h:145  Pos: (3, 4) f:170 g:25 h:145
# Closed: 1818   Open:1818
# Not for times straight please!!
# 	DOING (3, 3)
# child 4
# child 5
# Closed: 1819   Open:1819
# Not for times straight please!!
# 	DOING (3, 1)
# child 3
# child 4
# Pos: (3, 2) f:211 g:30 h:181  Pos: (3, 2) f:204 g:23 h:181
# Closed: 1820   Open:1820
# 	DOING (3, 3)
# child 5
# child 5
# child 6
# Pos: (4, 3) f:180 g:35 h:145  Pos: (4, 3) f:177 g:32 h:145
# Pos: (4, 3) f:180 g:35 h:145  Pos: (4, 3) f:177 g:32 h:145
# Pos: (4, 3) f:181 g:36 h:145  Pos: (4, 3) f:177 g:32 h:145
# Closed: 1822   Open:1822
# Not for times straight please!!
# 	DOING (4, 2)
# child 5
# child 6
# Pos: (4, 3) f:177 g:32 h:145  Pos: (4, 3) f:175 g:30 h:145
# Pos: (4, 3) f:177 g:32 h:145  Pos: (4, 3) f:175 g:30 h:145
# Pos: (4, 3) f:177 g:32 h:145  Pos: (4, 3) f:175 g:30 h:145
# Pos: (4, 3) f:177 g:32 h:145  Pos: (4, 3) f:175 g:30 h:145
# Closed: 1823   Open:1823
# Not for times straight please!!
# 	DOING (3, 1)
# child 3
# child 4
# Closed: 1824   Open:1824
# 	DOING (5, 1)
# child 3
# child 5
# Pos: (4, 1) f:214 g:29 h:185  Pos: (4, 1) f:212 g:27 h:185
# child 4
# Closed: 1826   Open:1826
# 	DOING (4, 4)
# child 6
# child 5
# child 5
# Pos: (5, 4) f:148 g:35 h:113  Pos: (5, 4) f:147 g:34 h:113
# Closed: 1828   Open:1828
# Not for times straight please!!
# 	DOING (3, 3)
# child 4
# child 5
# Closed: 1829   Open:1829
# 	DOING (5, 3)
# child 5
# child 6
# child 7
# Closed: 1831   Open:1831
# 	DOING (5, 1)
# child 3
# child 5
# child 4
# Closed: 1833   Open:1833
# 	DOING (5, 3)
# child 5
# child 6
# child 7
# Closed: 1835   Open:1835
# Not for times straight please!!
# 	DOING (6, 2)
# child 4
# child 7
# Pos: (6, 3) f:154 g:37 h:117  Pos: (6, 3) f:151 g:34 h:117
# Pos: (6, 3) f:154 g:37 h:117  Pos: (6, 3) f:151 g:34 h:117
# Pos: (6, 3) f:154 g:37 h:117  Pos: (6, 3) f:151 g:34 h:117
# Pos: (6, 3) f:154 g:37 h:117  Pos: (6, 3) f:151 g:34 h:117
# Pos: (6, 3) f:154 g:37 h:117  Pos: (6, 3) f:151 g:34 h:117
# Pos: (6, 3) f:154 g:37 h:117  Pos: (6, 3) f:151 g:34 h:117
# Pos: (6, 3) f:154 g:37 h:117  Pos: (6, 3) f:151 g:34 h:117
# Pos: (6, 3) f:154 g:37 h:117  Pos: (6, 3) f:151 g:34 h:117
# Pos: (6, 3) f:154 g:37 h:117  Pos: (6, 3) f:151 g:34 h:117
# Pos: (6, 3) f:154 g:37 h:117  Pos: (6, 3) f:151 g:34 h:117
# Pos: (6, 3) f:154 g:37 h:117  Pos: (6, 3) f:151 g:34 h:117
# Pos: (6, 3) f:154 g:37 h:117  Pos: (6, 3) f:151 g:34 h:117
# Pos: (6, 3) f:154 g:37 h:117  Pos: (6, 3) f:151 g:34 h:117
# Pos: (6, 3) f:154 g:37 h:117  Pos: (6, 3) f:151 g:34 h:117
# Closed: 1836   Open:1836
# Not for times straight please!!
# 	DOING (4, 2)
# child 5
# child 6
# Pos: (4, 3) f:180 g:35 h:145  Pos: (4, 3) f:175 g:30 h:145
# Pos: (4, 3) f:181 g:36 h:145  Pos: (4, 3) f:175 g:30 h:145
# Pos: (4, 3) f:181 g:36 h:145  Pos: (4, 3) f:175 g:30 h:145
# Closed: 1837   Open:1837
# Not for times straight please!!
# 	DOING (3, 1)
# child 3
# child 4
# Pos: (3, 2) f:211 g:30 h:181  Pos: (3, 2) f:204 g:23 h:181
# Closed: 1838   Open:1838
# 	DOING (5, 1)
# child 3
# child 5
# Pos: (4, 1) f:214 g:29 h:185  Pos: (4, 1) f:212 g:27 h:185
# child 4
# Pos: (6, 1) f:188 g:31 h:157  Pos: (6, 1) f:183 g:26 h:157
# Closed: 1840   Open:1840
# 	DOING (5, 1)
# child 3
# child 5
# child 4
# Closed: 1842   Open:1842
# 	DOING (4, 0)
# child 5
# child 1
# Closed: 1843   Open:1843
# Not for times straight please!!
# 	DOING (4, 2)
# child 5
# child 6
# Closed: 1844   Open:1844
# 	DOING (5, 1)
# child 3
# child 5
# Pos: (4, 1) f:213 g:28 h:185  Pos: (4, 1) f:212 g:27 h:185
# Pos: (4, 1) f:214 g:29 h:185  Pos: (4, 1) f:212 g:27 h:185
# child 4
# Closed: 1846   Open:1846
# 	DOING (4, 4)
# child 6
# child 5
# child 5
# Pos: (5, 4) f:148 g:35 h:113  Pos: (5, 4) f:147 g:34 h:113
# Pos: (5, 4) f:148 g:35 h:113  Pos: (5, 4) f:147 g:34 h:113
# Closed: 1848   Open:1848
# Not for times straight please!!
# 	DOING (3, 3)
# child 4
# child 5
# Closed: 1849   Open:1849
# 	DOING (5, 3)
# child 5
# child 6
# child 7
# Closed: 1851   Open:1851
# 	DOING (1, 5)
# child 4
# child 3
# child 4
# Closed: 1853   Open:1853
# 	DOING (1, 3)
# child 4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/marcialr/repos/AOC/aoc2023/day17.ipynb Cell 2 line 1
#     <a href='vscode-notebook-cell:/home/marcialr/repos/AOC/aoc2023/day17.ipynb#W1sZmlsZQ%3D%3D?line=144'>145</a> if __name__ == '__main__':
#     <a href='vscode-notebook-cell:/home/marcialr/repos/AOC/aoc2023/day17.ipynb#W1sZmlsZQ%3D%3D?line=145'>146</a>     maze = [[int(c) for c in x] for x in puzzle.test]
# --> <a href='vscode-notebook-cell:/home/marcialr/repos/AOC/aoc2023/day17.ipynb#W1sZmlsZQ%3D%3D?line=146'>147</a>     main(maze)
#
# /home/marcialr/repos/AOC/aoc2023/day17.ipynb Cell 2 line 1
#     <a href='vscode-notebook-cell:/home/marcialr/repos/AOC/aoc2023/day17.ipynb#W1sZmlsZQ%3D%3D?line=137'>138</a> start = (0, 0)
#     <a href='vscode-notebook-cell:/home/marcialr/repos/AOC/aoc2023/day17.ipynb#W1sZmlsZQ%3D%3D?line=138'>139</a> end = (len(maze)-1, len(maze[0])-1)
# --> <a href='vscode-notebook-cell:/home/marcialr/repos/AOC/aoc2023/day17.ipynb#W1sZmlsZQ%3D%3D?line=140'>141</a> path = astar(maze, start, end)
#     <a href='vscode-notebook-cell:/home/marcialr/repos/AOC/aoc2023/day17.ipynb#W1sZmlsZQ%3D%3D?line=141'>142</a> print(path)
#
# /home/marcialr/repos/AOC/aoc2023/day17.ipynb Cell 2 line 1
#     <a href='vscode-notebook-cell:/home/marcialr/repos/AOC/aoc2023/day17.ipynb#W1sZmlsZQ%3D%3D?line=104'>105</a> if child.position == open_node.position:
#     <a href='vscode-notebook-cell:/home/marcialr/repos/AOC/aoc2023/day17.ipynb#W1sZmlsZQ%3D%3D?line=105'>106</a>     if child.f < open_node.f:
# --> <a href='vscode-notebook-cell:/home/marcialr/repos/AOC/aoc2023/day17.ipynb#W1sZmlsZQ%3D%3D?line=106'>107</a>         print(f"{open_node}  {child}")
#     <a href='vscode-notebook-cell:/home/marcialr/repos/AOC/aoc2023/day17.ipynb#W1sZmlsZQ%3D%3D?line=107'>108</a>         open_node.f = child.f
#     <a href='vscode-notebook-cell:/home/marcialr/repos/AOC/aoc2023/day17.ipynb#W1sZmlsZQ%3D%3D?line=108'>109</a>         open_node.g = child.g
#
# File ~/.local/lib/python3.9/site-packages/ipykernel/iostream.py:651, in OutStream.write(self, string)
#     649 is_child = not self._is_master_process()
#     650 # only touch the buffer in the IO thread to avoid races
# --> 651 with self._buffer_lock:
#     652     self._buffer.write(string)
#     653 if is_child:
#     654     # mp.Pool cannot be trusted to flush promptly (or ever),
#     655     # and this helps.
#
# KeyboardInterrupt:

# %%
i = ["2738", "7696"]
print ([[int(c) for c in x] for x in puzzle.test])
# Out:
# [[2, 4, 1, 3, 4, 3, 2, 3, 1, 1, 3, 2, 3], [3, 2, 1, 5, 4, 5, 3, 5, 3, 5, 6, 2, 3], [3, 2, 5, 5, 2, 4, 5, 6, 5, 4, 2, 5, 4], [3, 4, 4, 6, 5, 8, 5, 8, 4, 5, 4, 5, 2], [4, 5, 4, 6, 6, 5, 7, 8, 6, 7, 5, 3, 6], [1, 4, 3, 8, 5, 9, 8, 7, 9, 8, 4, 5, 4], [4, 4, 5, 7, 8, 7, 6, 9, 8, 7, 7, 6, 6], [3, 6, 3, 7, 8, 7, 7, 9, 7, 9, 6, 5, 3], [4, 6, 5, 4, 9, 6, 7, 9, 8, 6, 8, 8, 7], [4, 5, 6, 4, 6, 7, 9, 9, 8, 6, 4, 5, 3], [1, 2, 2, 4, 6, 8, 6, 8, 6, 5, 5, 6, 3], [2, 5, 4, 6, 5, 4, 8, 8, 8, 7, 7, 3, 5], [4, 3, 2, 2, 6, 7, 4, 6, 5, 5, 5, 3, 3]]

# %%
a=1
b=1
c=2
if a and b and c:
    print ('yes')
# Out:
# yes

# %%
a and b and c
# Out:
# 2
