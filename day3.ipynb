# %%
from tools import get_puzzle, show_problem_1
TODAY = 3
puzzle = get_puzzle(TODAY)
show_problem_1(puzzle)
# Out:
# ## --- Day 3: Gear Ratios ---
#
#
# You and the Elf eventually reach a [gondola lift](https://en.wikipedia.org/wiki/Gondola_lift) station; he says the gondola lift will take you up to the **water source** , but this is as far as he can bring you. You go inside.
#
#
# It doesn't take long to find the gondolas, but there seems to be a problem: they're not moving.
#
#
# "Aaah!"
#
#
# You turn around to see a slightly-greasy Elf with a wrench and a look of surprise. "Sorry, I wasn't expecting anyone! The gondola lift isn't working right now; it'll still be a while before I can fix it." You offer to help.
#
#
# The engineer explains that an engine part seems to be missing from the engine, but nobody can figure out which one. If you can **add up all the part numbers** in the engine schematic, it should be easy to work out which part is missing.
#
#
# The engine schematic (your puzzle input) consists of a visual representation of the engine. There are lots of numbers and symbols you don't really understand, but apparently **any number adjacent to a symbol** , even diagonally, is a "part number" and should be included in your sum. (Periods (.``) do not count as a symbol.)
#
#
# Here is an example engine schematic:
#
#
# ```
#  467..114..
#  ...*......
#  ..35..633.
#  ......#...
#  617*......
#  .....+.58.
#  ..592.....
#  ......755.
#  ...$.*....
#  .664.598..
#
# ```
#
#
# In this schematic, two numbers are **not** part numbers because they are not adjacent to a symbol:114``(top right) and58``(middle right). Every other number is adjacent to a symbol and so **is** a part number; their sum is4361``.
#
#
# Of course, the actual engine schematic is much larger. **What is the sum of all of the part numbers in the engine schematic?**

# %%
def is_num(ch):
    return  48 <= ord(ch) <= 57

def is_simbol(ch):
    return  ch != '.' and not is_num(ch)

def valid_columns(data, number, col, is_row):
    if is_row:
        sol = [col-1, col+len(number)]
    else:
        sol = list(range(col-1, col+len(number)+1))
    
    for s in sol:
        if s >=0 and s < len(data[col]):
            yield s


def valid_rows(data, number, row):
    for r in [row-1, row, row +1]:
        if r < 0: continue
        if r == len(data): continue
        yield r, r==row

def verify_not_adjacent_symbol(data, number, row, col):
    for r, is_row in valid_rows(data, number, row):
        for c in valid_columns(data, number, col, is_row):
            if is_simbol (data[r][c]):
                print (f'{number} es valido gracias a {data[r][c]} en {r},{c}')
                return True
    #print (f'{number} NO ES VALIDO')
    return False
    
    
def get_nums(data):
    for row in range(len(data)):
        print (f"\nROW {row}" )
        for (num, pos) in get_numbers(data, row):
            #print(f"en row {row} esta {num} en pos {pos}")
            yield int(num)

def get_numbers(data,row):
    number = None
    for col in range(len(data[row])):
        #print(f"{col} , {data[row][col]}")
    
        if not is_num(data[row][col]):
            if number:
                if verify_not_adjacent_symbol(data, number, row, idx):
                    yield number, idx
                
            number = None
            idx = None
            continue
        if number:
            number += data[row][col]
        else:
            
            number = data[row][col]
            #print(f"found {number}")
            idx = col
    print (f"Hay {number}")
    if number:                            
        yield number, idx
     
    

    
def solution_1(data):
    return sum(get_nums(data))

print(solution_1 (puzzle.test))
#assert solution_1 (puzzle.test) ==4361
#print( f"Solution 1:  {solution_1 (puzzle.data)} is the sum of all of the calibration values")
# 526098 too high  526098

"""
467..114.5
...*6...66
..35..633.
......#...
617*......
.....+.58.
..592.....
......755.
...$.*....
.664.598..
"""
# Out:
# ROW 0
# 672 es valido gracias a * en 1,7
# 391 es valido gracias a * en 1,19
# 591 es valido gracias a * en 1,25
# 828 es valido gracias a * en 1,37
# 738 es valido gracias a * en 1,63
# 803 es valido gracias a * en 1,92
# 472 es valido gracias a $ en 1,94
# 714 es valido gracias a * en 1,135
# 840 es valido gracias a * en 1,135
# Hay None
#
# ROW 1
# 631 es valido gracias a % en 1,49
# 703 es valido gracias a * en 2,56
# 12 es valido gracias a @ en 2,65
# 652 es valido gracias a @ en 2,75
# 368 es valido gracias a * en 2,109
# 769 es valido gracias a * en 1,114
# 148 es valido gracias a * en 1,114
# Hay None
#
# ROW 2
# 411 es valido gracias a * en 1,7
# 2 es valido gracias a * en 1,19
# 837 es valido gracias a * en 1,25
# 121 es valido gracias a & en 3,27
# 511 es valido gracias a * en 1,37
# 48 es valido gracias a * en 3,58
# 422 es valido gracias a * en 1,63
# 311 es valido gracias a * en 1,92
# 887 es valido gracias a * en 3,102
# 457 es valido gracias a * en 3,125
# Hay 595
#
# ROW 3
# 328 es valido gracias a * en 3,8
# 144 es valido gracias a * en 2,56
# 138 es valido gracias a * en 4,78
# 48 es valido gracias a * en 4,95
# 682 es valido gracias a * en 2,109
# 777 es valido gracias a * en 4,134
# Hay None
#
# ROW 4
# 144 es valido gracias a * en 3,8
# 207 es valido gracias a % en 5,43
# 813 es valido gracias a * en 3,58
# 139 es valido gracias a * en 5,75
# 346 es valido gracias a + en 5,83
# 147 es valido gracias a * en 5,97
# 143 es valido gracias a * en 3,102
# 78 es valido gracias a # en 5,113
# 536 es valido gracias a @ en 3,121
# 79 es valido gracias a * en 3,125
# Hay None
#
# ROW 5
# 828 es valido gracias a + en 4,13
# 559 es valido gracias a * en 6,20
# 181 es valido gracias a * en 6,40
# 613 es valido gracias a * en 6,57
# 10 es valido gracias a / en 4,66
# 928 es valido gracias a & en 4,68
# 993 es valido gracias a * en 4,78
# 758 es valido gracias a * en 4,95
# 471 es valido gracias a + en 4,107
# 573 es valido gracias a * en 4,134
# Hay None
#
# ROW 6
# 164 es valido gracias a * en 6,20
# 132 es valido gracias a + en 7,30
# 47 es valido gracias a * en 5,75
# 313 es valido gracias a * en 5,97
# 411 es valido gracias a / en 5,116
# Hay None
#
# ROW 7
# 342 es valido gracias a * en 8,18
# 823 es valido gracias a * en 8,32
# 533 es valido gracias a * en 6,40
# 519 es valido gracias a = en 6,49
# 899 es valido gracias a * en 6,57
# 310 es valido gracias a * en 8,62
# 325 es valido gracias a * en 8,90
# 407 es valido gracias a * en 8,125
# Hay None
#
# ROW 8
# 515 es valido gracias a = en 9,3
# 916 es valido gracias a * en 9,11
# 961 es valido gracias a * en 9,69
# 827 es valido gracias a @ en 7,81
# 567 es valido gracias a - en 9,109
# 238 es valido gracias a = en 8,115
# 874 es valido gracias a * en 8,125
# 420 es valido gracias a # en 7,134
# Hay None
#
# ROW 9
# 207 es valido gracias a * en 8,18
# 882 es valido gracias a @ en 8,20
# 719 es valido gracias a * en 8,32
# 369 es valido gracias a * en 8,62
# 913 es valido gracias a * en 9,75
# 978 es valido gracias a * en 8,90
# 720 es valido gracias a = en 8,98
# Hay None
#
# ROW 10
# 306 es valido gracias a * en 9,11
# 182 es valido gracias a = en 11,62
# 534 es valido gracias a * en 9,69
# 229 es valido gracias a % en 9,93
# 744 es valido gracias a % en 11,106
# 918 es valido gracias a & en 11,135
# Hay None
#
# ROW 11
# 745 es valido gracias a * en 12,17
# 129 es valido gracias a * en 12,57
# 830 es valido gracias a & en 12,81
# 493 es valido gracias a + en 10,115
# 106 es valido gracias a = en 10,121
# Hay None
#
# ROW 12
# 209 es valido gracias a * en 12,17
# 17 es valido gracias a * en 13,22
# 910 es valido gracias a * en 13,40
# 90 es valido gracias a * en 12,57
# 496 es valido gracias a * en 13,67
# 896 es valido gracias a % en 11,88
# Hay None
#
# ROW 13
# 562 es valido gracias a = en 14,6
# 528 es valido gracias a / en 14,42
# 321 es valido gracias a * en 14,53
# 673 es valido gracias a * en 13,67
# 887 es valido gracias a * en 14,92
# 231 es valido gracias a % en 13,98
# 700 es valido gracias a * en 14,117
# Hay None
#
# ROW 14
# 988 es valido gracias a % en 13,4
# 944 es valido gracias a $ en 15,10
# 806 es valido gracias a @ en 13,28
# 519 es valido gracias a * en 13,40
# 146 es valido gracias a * en 15,80
# 554 es valido gracias a * en 15,113
# Hay None
#
# ROW 15
# 822 es valido gracias a * en 14,53
# 621 es valido gracias a * en 16,55
# 771 es valido gracias a / en 14,62
# 151 es valido gracias a * en 16,65
# 504 es valido gracias a - en 16,71
# 628 es valido gracias a * en 15,85
# 343 es valido gracias a * en 15,85
# 34 es valido gracias a * en 14,92
# 329 es valido gracias a * en 14,117
# 303 es valido gracias a * en 16,122
# 641 es valido gracias a * en 16,127
# Hay None
#
# ROW 16
# 361 es valido gracias a * en 17,23
# 347 es valido gracias a * en 16,35
# 524 es valido gracias a * en 16,35
# 538 es valido gracias a * en 17,40
# 790 es valido gracias a * en 15,80
# 933 es valido gracias a + en 15,96
# 724 es valido gracias a & en 15,98
# 699 es valido gracias a * en 17,107
# 262 es valido gracias a + en 15,135
# Hay None
#
# ROW 17
# 716 es valido gracias a % en 18,3
# 517 es valido gracias a + en 18,5
# 955 es valido gracias a $ en 17,50
# 544 es valido gracias a * en 16,55
# 238 es valido gracias a * en 18,62
# 593 es valido gracias a * en 16,65
# 399 es valido gracias a * en 18,76
# 241 es valido gracias a * en 16,122
# 930 es valido gracias a * en 16,127
# Hay None
#
# ROW 18
# 744 es valido gracias a + en 17,12
# 550 es valido gracias a * en 17,23
# 131 es valido gracias a # en 18,33
# 964 es valido gracias a * en 17,40
# 234 es valido gracias a % en 19,58
# 856 es valido gracias a # en 17,84
# 809 es valido gracias a = en 17,87
# 450 es valido gracias a / en 19,91
# 332 es valido gracias a * en 17,107
# 419 es valido gracias a * en 19,115
# 389 es valido gracias a * en 19,132
# Hay None
#
# ROW 19
# 264 es valido gracias a * en 20,7
# 798 es valido gracias a * en 20,26
# 816 es valido gracias a * en 20,50
# 228 es valido gracias a * en 18,62
# 501 es valido gracias a * en 18,76
# 224 es valido gracias a * en 20,81
# 645 es valido gracias a % en 18,99
# 499 es valido gracias a * en 19,115
# Hay None
#
# ROW 20
# 939 es valido gracias a * en 21,18
# 795 es valido gracias a * en 20,50
# 789 es valido gracias a * en 21,109
# 907 es valido gracias a * en 19,124
# 647 es valido gracias a * en 19,132
# Hay None
#
# ROW 21
# 612 es valido gracias a * en 20,7
# 612 es valido gracias a * en 22,23
# 291 es valido gracias a * en 20,26
# 592 es valido gracias a @ en 20,32
# 567 es valido gracias a $ en 22,59
# 391 es valido gracias a * en 20,81
# 387 es valido gracias a * en 22,113
# 64 es valido gracias a * en 22,130
# Hay None
#
# ROW 22
# 24 es valido gracias a * en 21,18
# 814 es valido gracias a # en 21,41
# 346 es valido gracias a * en 23,73
# 444 es valido gracias a * en 23,90
# 833 es valido gracias a * en 21,109
# 845 es valido gracias a @ en 23,124
# Hay None
#
# ROW 23
# 303 es valido gracias a = en 24,12
# 605 es valido gracias a * en 22,23
# 326 es valido gracias a $ en 24,31
# 108 es valido gracias a + en 24,38
# 56 es valido gracias a = en 22,50
# 842 es valido gracias a = en 23,56
# 387 es valido gracias a / en 22,67
# 478 es valido gracias a - en 23,79
# 272 es valido gracias a = en 23,85
# 778 es valido gracias a * en 22,113
# 299 es valido gracias a = en 23,121
# 722 es valido gracias a * en 22,130
# Hay None
#
# ROW 24
# 484 es valido gracias a = en 24,9
# 753 es valido gracias a * en 25,19
# 449 es valido gracias a % en 23,46
# 559 es valido gracias a * en 23,62
# 144 es valido gracias a * en 23,73
# 695 es valido gracias a * en 23,90
# 675 es valido gracias a # en 23,101
# Hay 253
#
# ROW 25
# 987 es valido gracias a * en 26,93
# 200 es valido gracias a & en 26,107
# 445 es valido gracias a * en 26,119
# Hay None
#
# ROW 26
# 825 es valido gracias a - en 25,3
# 603 es valido gracias a * en 25,19
# 544 es valido gracias a * en 25,29
# 634 es valido gracias a * en 25,29
# 432 es valido gracias a - en 27,57
# 875 es valido gracias a = en 26,63
# 738 es valido gracias a / en 27,70
# 731 es valido gracias a * en 27,89
# 488 es valido gracias a * en 25,113
# 363 es valido gracias a * en 25,113
# 663 es valido gracias a @ en 27,126
# Hay 876
#
# ROW 27
# 470 es valido gracias a * en 26,93
# 314 es valido gracias a * en 28,102
# 145 es valido gracias a * en 28,102
# 277 es valido gracias a * en 26,119
# 234 es valido gracias a - en 27,135
# Hay None
#
# ROW 28
# 221 es valido gracias a * en 29,19
# 892 es valido gracias a * en 29,34
# 284 es valido gracias a & en 29,38
# 473 es valido gracias a # en 27,44
# 342 es valido gracias a * en 29,63
# 622 es valido gracias a * en 29,63
# 707 es valido gracias a * en 29,78
# 413 es valido gracias a * en 27,84
# 984 es valido gracias a * en 27,89
# Hay None
#
# ROW 29
# 351 es valido gracias a % en 29,74
# 226 es valido gracias a / en 28,109
# 155 es valido gracias a - en 30,122
# 973 es valido gracias a + en 29,131
# Hay None
#
# ROW 30
# 177 es valido gracias a $ en 29,14
# 991 es valido gracias a * en 29,19
# 268 es valido gracias a * en 29,34
# 532 es valido gracias a = en 30,51
# 277 es valido gracias a * en 31,64
# 183 es valido gracias a * en 29,78
# 935 es valido gracias a * en 30,85
# 917 es valido gracias a * en 31,99
# 825 es valido gracias a # en 31,113
# Hay None
#
# ROW 31
# 413 es valido gracias a / en 32,27
# 304 es valido gracias a = en 32,39
# 384 es valido gracias a / en 30,59
# 748 es valido gracias a * en 30,85
# 955 es valido gracias a * en 30,105
# 885 es valido gracias a * en 32,128
# 970 es valido gracias a * en 32,128
# Hay None
#
# ROW 32
# 44 es valido gracias a + en 31,5
# 627 es valido gracias a % en 31,7
# 368 es valido gracias a # en 31,24
# 314 es valido gracias a * en 31,64
# 293 es valido gracias a * en 33,69
# 102 es valido gracias a / en 31,94
# 108 es valido gracias a * en 31,99
# Hay None
#
# ROW 33
# 733 es valido gracias a / en 34,44
# 433 es valido gracias a - en 34,46
# 889 es valido gracias a - en 34,79
# 661 es valido gracias a * en 34,108
# 358 es valido gracias a - en 33,119
# 281 es valido gracias a = en 34,134
# Hay None
#
# ROW 34
# 35 es valido gracias a = en 33,6
# 834 es valido gracias a = en 33,32
# 699 es valido gracias a / en 34,35
# 461 es valido gracias a * en 33,69
# 374 es valido gracias a $ en 33,126
# Hay 412
#
# ROW 35
# 763 es valido gracias a * en 36,11
# 201 es valido gracias a $ en 34,17
# 392 es valido gracias a @ en 36,53
# 96 es valido gracias a * en 36,75
# 723 es valido gracias a * en 36,81
# 340 es valido gracias a * en 34,88
# 327 es valido gracias a * en 36,98
# 736 es valido gracias a * en 36,102
# 1 es valido gracias a * en 34,108
# 897 es valido gracias a $ en 35,110
# Hay None
#
# ROW 36
# 512 es valido gracias a * en 36,5
# 221 es valido gracias a $ en 35,22
# 125 es valido gracias a $ en 36,40
# 257 es valido gracias a / en 37,45
# 277 es valido gracias a / en 37,79
# Hay None
#
# ROW 37
# 301 es valido gracias a * en 36,5
# 694 es valido gracias a * en 36,11
# 54 es valido gracias a * en 38,27
# 611 es valido gracias a * en 38,54
# 596 es valido gracias a * en 36,75
# 100 es valido gracias a * en 36,81
# 164 es valido gracias a = en 38,94
# 801 es valido gracias a * en 36,98
# 596 es valido gracias a * en 36,102
# 490 es valido gracias a * en 38,107
# 361 es valido gracias a & en 37,115
# 415 es valido gracias a * en 38,129
# 412 es valido gracias a @ en 36,135
# Hay None
#
# ROW 38
# 243 es valido gracias a & en 39,19
# 927 es valido gracias a * en 38,27
# 29 es valido gracias a * en 38,39
# 293 es valido gracias a * en 38,39
# 645 es valido gracias a * en 38,54
# 862 es valido gracias a * en 38,65
# 2 es valido gracias a * en 38,65
# Hay None
#
# ROW 39
# 906 es valido gracias a * en 40,33
# 500 es valido gracias a % en 40,48
# 125 es valido gracias a * en 40,73
# 613 es valido gracias a * en 40,73
# 435 es valido gracias a * en 40,97
# 984 es valido gracias a * en 38,107
# 725 es valido gracias a - en 39,117
# 531 es valido gracias a * en 40,119
# 711 es valido gracias a * en 38,129
# 79 es valido gracias a $ en 38,132
# Hay None
#
# ROW 40
# 817 es valido gracias a # en 41,5
# 450 es valido gracias a $ en 39,12
# 431 es valido gracias a * en 41,45
# 739 es valido gracias a @ en 39,91
# Hay None
#
# ROW 41
# 237 es valido gracias a * en 42,17
# 122 es valido gracias a & en 42,24
# 66 es valido gracias a * en 42,27
# 942 es valido gracias a * en 40,33
# 73 es valido gracias a * en 40,97
# 883 es valido gracias a + en 42,104
# 644 es valido gracias a * en 40,119
# Hay None
#
# ROW 42
# 863 es valido gracias a * en 43,4
# 98 es valido gracias a * en 41,45
# 283 es valido gracias a & en 43,51
# 532 es valido gracias a % en 43,64
# 750 es valido gracias a * en 43,69
# 594 es valido gracias a * en 42,112
# Hay None
#
# ROW 43
# 451 es valido gracias a * en 42,17
# 623 es valido gracias a * en 42,27
# 50 es valido gracias a * en 43,69
# 44 es valido gracias a * en 44,77
# 123 es valido gracias a * en 42,87
# 951 es valido gracias a # en 42,96
# 62 es valido gracias a * en 42,112
# 943 es valido gracias a * en 44,116
# 365 es valido gracias a * en 44,125
# Hay None
#
# ROW 44
# 639 es valido gracias a * en 43,4
# 827 es valido gracias a @ en 45,20
# 265 es valido gracias a * en 45,24
# 132 es valido gracias a * en 43,34
# 354 es valido gracias a * en 43,39
# 127 es valido gracias a * en 43,39
# 350 es valido gracias a * en 45,56
# Hay None
#
# ROW 45
# 41 es valido gracias a * en 46,9
# 175 es valido gracias a # en 45,12
# 247 es valido gracias a @ en 46,61
# 353 es valido gracias a * en 46,65
# 44 es valido gracias a * en 44,77
# 912 es valido gracias a - en 45,85
# 757 es valido gracias a * en 46,94
# 144 es valido gracias a * en 46,113
# 481 es valido gracias a * en 44,116
# 693 es valido gracias a % en 44,121
# 271 es valido gracias a * en 44,125
# 993 es valido gracias a = en 46,135
# Hay None
#
# ROW 46
# 993 es valido gracias a * en 45,24
# 707 es valido gracias a * en 45,27
# 857 es valido gracias a * en 46,36
# 375 es valido gracias a + en 45,49
# 90 es valido gracias a * en 45,56
# 386 es valido gracias a # en 45,69
# 403 es valido gracias a @ en 47,79
# 208 es valido gracias a & en 47,129
# Hay None
#
# ROW 47
# 343 es valido gracias a * en 46,9
# 117 es valido gracias a * en 46,36
# 637 es valido gracias a $ en 48,44
# 345 es valido gracias a * en 48,55
# 43 es valido gracias a * en 46,65
# 662 es valido gracias a * en 47,73
# 908 es valido gracias a * en 46,94
# 956 es valido gracias a % en 48,105
# 908 es valido gracias a * en 46,113
# Hay None
#
# ROW 48
# 389 es valido gracias a * en 49,3
# 670 es valido gracias a & en 47,31
# 564 es valido gracias a * en 47,73
# Hay None
#
# ROW 49
# 435 es valido gracias a & en 48,16
# 913 es valido gracias a * en 50,37
# 574 es valido gracias a * en 48,55
# 149 es valido gracias a = en 48,59
# 962 es valido gracias a % en 50,86
# 77 es valido gracias a * en 50,115
# 641 es valido gracias a + en 48,121
# 514 es valido gracias a * en 50,127
# Hay None
#
# ROW 50
# 448 es valido gracias a * en 49,3
# 892 es valido gracias a * en 49,23
# 381 es valido gracias a # en 51,27
# 593 es valido gracias a * en 51,34
# 403 es valido gracias a * en 50,66
# 149 es valido gracias a * en 50,66
# 863 es valido gracias a * en 50,92
# 954 es valido gracias a * en 50,92
# 373 es valido gracias a - en 50,103
# 663 es valido gracias a # en 51,133
# Hay None
#
# ROW 51
# 922 es valido gracias a * en 50,37
# 950 es valido gracias a * en 52,49
# 993 es valido gracias a * en 52,77
# 379 es valido gracias a + en 50,106
# 450 es valido gracias a * en 50,115
# 877 es valido gracias a * en 50,127
# 804 es valido gracias a + en 50,129
# Hay None
#
# ROW 52
# 768 es valido gracias a * en 53,17
# 198 es valido gracias a * en 51,34
# 160 es valido gracias a * en 52,49
# 820 es valido gracias a * en 53,62
# 169 es valido gracias a * en 53,85
# 555 es valido gracias a * en 52,96
# 257 es valido gracias a * en 53,104
# Hay None
#
# ROW 53
# 68 es valido gracias a * en 52,25
# 281 es valido gracias a - en 52,32
# 871 es valido gracias a # en 54,39
# 875 es valido gracias a * en 52,77
# 169 es valido gracias a * en 52,96
# Hay None
#
# ROW 54
# 587 es valido gracias a * en 53,17
# 48 es valido gracias a @ en 55,47
# 251 es valido gracias a @ en 55,53
# 316 es valido gracias a @ en 54,58
# 848 es valido gracias a * en 53,62
# 303 es valido gracias a * en 53,85
# 931 es valido gracias a * en 53,104
# 132 es valido gracias a * en 55,106
# 790 es valido gracias a @ en 53,127
# Hay None
#
# ROW 55
# 205 es valido gracias a * en 54,4
# 572 es valido gracias a @ en 54,11
# 709 es valido gracias a * en 56,65
# 611 es valido gracias a % en 56,72
# 270 es valido gracias a * en 56,94
# 165 es valido gracias a * en 56,114
# 783 es valido gracias a * en 56,123
# 790 es valido gracias a & en 56,133
# Hay None
#
# ROW 56
# 709 es valido gracias a # en 57,37
# 826 es valido gracias a & en 55,41
# 882 es valido gracias a * en 56,65
# 775 es valido gracias a $ en 57,77
# 391 es valido gracias a = en 55,87
# 5 es valido gracias a * en 55,106
# 179 es valido gracias a * en 56,114
# 47 es valido gracias a * en 56,123
# Hay None
#
# ROW 57
# 804 es valido gracias a = en 58,57
# 161 es valido gracias a * en 58,79
# 837 es valido gracias a * en 56,94
# 904 es valido gracias a $ en 57,128
# 176 es valido gracias a * en 58,135
# Hay None
#
# ROW 58
# 70 es valido gracias a @ en 57,20
# 868 es valido gracias a * en 59,39
# 357 es valido gracias a * en 59,65
# 252 es valido gracias a * en 59,71
# 707 es valido gracias a * en 59,99
# 898 es valido gracias a * en 57,111
# 139 es valido gracias a * en 57,111
# 704 es valido gracias a * en 59,121
# Hay None
#
# ROW 59
# 307 es valido gracias a * en 59,39
# 510 es valido gracias a * en 60,47
# 17 es valido gracias a * en 58,79
# 501 es valido gracias a * en 60,82
# 855 es valido gracias a * en 58,135
# Hay None
#
# ROW 60
# 745 es valido gracias a $ en 61,14
# 451 es valido gracias a * en 61,29
# 689 es valido gracias a % en 61,49
# 980 es valido gracias a @ en 61,57
# 670 es valido gracias a @ en 60,60
# 594 es valido gracias a * en 59,65
# 716 es valido gracias a * en 59,71
# 565 es valido gracias a * en 59,99
# 622 es valido gracias a @ en 59,116
# 793 es valido gracias a * en 59,121
# Hay None
#
# ROW 61
# 890 es valido gracias a * en 62,8
# 73 es valido gracias a * en 62,17
# 422 es valido gracias a % en 62,22
# 977 es valido gracias a & en 61,36
# 324 es valido gracias a * en 60,47
# 29 es valido gracias a * en 62,75
# 945 es valido gracias a * en 60,82
# 298 es valido gracias a - en 61,107
# Hay 642
#
# ROW 62
# 645 es valido gracias a $ en 62,61
# 150 es valido gracias a * en 63,81
# 434 es valido gracias a * en 61,90
# 259 es valido gracias a * en 61,90
# 609 es valido gracias a * en 62,99
# 560 es valido gracias a * en 62,99
# 266 es valido gracias a * en 63,123
# 524 es valido gracias a # en 61,126
# Hay None
#
# ROW 63
# 203 es valido gracias a * en 62,8
# 133 es valido gracias a * en 62,17
# 596 es valido gracias a = en 64,28
# 619 es valido gracias a * en 64,31
# 676 es valido gracias a * en 64,66
# 107 es valido gracias a - en 62,71
# 811 es valido gracias a * en 62,75
# 115 es valido gracias a / en 62,109
# 178 es valido gracias a / en 62,134
# Hay None
#
# ROW 64
# 157 es valido gracias a * en 63,50
# 682 es valido gracias a * en 63,50
# 262 es valido gracias a * en 65,61
# 196 es valido gracias a * en 63,81
# 707 es valido gracias a * en 65,100
# 386 es valido gracias a * en 63,123
# Hay None
#
# ROW 65
# 871 es valido gracias a * en 66,12
# 605 es valido gracias a @ en 66,27
# 721 es valido gracias a * en 64,31
# 867 es valido gracias a * en 64,66
# 685 es valido gracias a $ en 64,88
# 866 es valido gracias a * en 66,92
# 602 es valido gracias a @ en 66,114
# 628 es valido gracias a * en 66,132
# Hay None
#
# ROW 66
# 413 es valido gracias a * en 67,20
# 372 es valido gracias a * en 65,61
# 277 es valido gracias a * en 67,80
# 166 es valido gracias a * en 65,100
# 656 es valido gracias a * en 67,127
# Hay 748
#
# ROW 67
# 841 es valido gracias a # en 66,6
# 664 es valido gracias a * en 66,12
# 422 es valido gracias a + en 68,25
# 945 es valido gracias a * en 68,53
# 959 es valido gracias a * en 66,92
# 887 es valido gracias a * en 66,132
# Hay None
#
# ROW 68
# 311 es valido gracias a * en 67,20
# 296 es valido gracias a * en 68,31
# 497 es valido gracias a * en 68,31
# 751 es valido gracias a @ en 69,42
# 269 es valido gracias a % en 67,67
# 875 es valido gracias a * en 67,80
# 36 es valido gracias a * en 67,127
# Hay None
#
# ROW 69
# 834 es valido gracias a + en 70,12
# 708 es valido gracias a * en 68,53
# 87 es valido gracias a % en 68,84
# 298 es valido gracias a = en 70,91
# 471 es valido gracias a * en 69,95
# 463 es valido gracias a - en 68,110
# Hay None
#
# ROW 70
# 739 es valido gracias a * en 71,19
# 265 es valido gracias a $ en 69,104
# 642 es valido gracias a * en 71,107
# Hay None
#
# ROW 71
# 871 es valido gracias a * en 71,38
# 314 es valido gracias a * en 71,38
# 127 es valido gracias a * en 72,49
# 36 es valido gracias a $ en 72,52
# 639 es valido gracias a * en 72,58
# 196 es valido gracias a * en 72,58
# 48 es valido gracias a * en 72,65
# 96 es valido gracias a * en 72,83
# 785 es valido gracias a / en 71,94
# 854 es valido gracias a = en 71,113
# 607 es valido gracias a = en 71,122
# 542 es valido gracias a - en 72,126
# Hay None
#
# ROW 72
# 254 es valido gracias a * en 71,19
# 591 es valido gracias a / en 73,23
# 35 es valido gracias a * en 73,75
# 150 es valido gracias a * en 71,107
# 340 es valido gracias a * en 73,134
# Hay None
#
# ROW 73
# 224 es valido gracias a * en 74,7
# 214 es valido gracias a * en 73,28
# 949 es valido gracias a * en 72,49
# 455 es valido gracias a * en 72,65
# 377 es valido gracias a * en 72,83
# 88 es valido gracias a @ en 72,87
# 823 es valido gracias a * en 74,108
# 582 es valido gracias a & en 74,117
# Hay None
#
# ROW 74
# 643 es valido gracias a * en 75,18
# 901 es valido gracias a * en 73,28
# 191 es valido gracias a = en 73,35
# 267 es valido gracias a * en 75,43
# 293 es valido gracias a * en 75,53
# 194 es valido gracias a * en 73,75
# 266 es valido gracias a * en 75,81
# 987 es valido gracias a * en 75,99
# 545 es valido gracias a * en 73,134
# Hay None
#
# ROW 75
# 604 es valido gracias a * en 74,7
# 583 es valido gracias a * en 76,12
# 742 es valido gracias a * en 75,31
# 365 es valido gracias a + en 76,83
# 880 es valido gracias a * en 74,108
# 55 es valido gracias a * en 76,114
# 540 es valido gracias a + en 74,122
# 520 es valido gracias a # en 75,127
# Hay None
#
# ROW 76
# 272 es valido gracias a * en 75,18
# 201 es valido gracias a * en 75,31
# 128 es valido gracias a * en 75,43
# 433 es valido gracias a * en 75,53
# 563 es valido gracias a $ en 75,62
# 281 es valido gracias a * en 76,75
# 77 es valido gracias a * en 76,75
# 540 es valido gracias a * en 75,81
# 979 es valido gracias a & en 76,94
# 134 es valido gracias a * en 75,99
# 514 es valido gracias a = en 75,104
# 46 es valido gracias a * en 77,129
# Hay None
#
# ROW 77
# 966 es valido gracias a * en 78,4
# 67 es valido gracias a * en 76,12
# 19 es valido gracias a * en 76,36
# 934 es valido gracias a & en 76,41
# 224 es valido gracias a + en 76,48
# 693 es valido gracias a * en 76,114
# 525 es valido gracias a $ en 78,134
# Hay None
#
# ROW 78
# 188 es valido gracias a * en 79,14
# 904 es valido gracias a * en 79,21
# 210 es valido gracias a # en 77,61
# 958 es valido gracias a * en 78,69
# 811 es valido gracias a * en 79,83
# 574 es valido gracias a * en 79,99
# 965 es valido gracias a * en 79,109
# 288 es valido gracias a * en 77,129
# 20 es valido gracias a * en 79,132
# Hay None
#
# ROW 79
# 213 es valido gracias a * en 78,4
# 137 es valido gracias a * en 79,21
# 325 es valido gracias a * en 78,31
# 406 es valido gracias a * en 80,60
# 34 es valido gracias a * en 78,69
# 406 es valido gracias a * en 80,91
# 867 es valido gracias a * en 80,119
# Hay None
#
# ROW 80
# 810 es valido gracias a * en 79,14
# 926 es valido gracias a + en 81,48
# 372 es valido gracias a - en 81,76
# 372 es valido gracias a * en 79,83
# 266 es valido gracias a $ en 79,97
# 716 es valido gracias a * en 79,99
# 985 es valido gracias a * en 79,109
# 1 es valido gracias a * en 79,132
# Hay None
#
# ROW 81
# 399 es valido gracias a * en 81,18
# 126 es valido gracias a * en 81,18
# 379 es valido gracias a * en 80,42
# 729 es valido gracias a - en 82,43
# 245 es valido gracias a * en 80,60
# 101 es valido gracias a * en 82,88
# 299 es valido gracias a * en 80,91
# 784 es valido gracias a * en 80,119
# Hay None
#
# ROW 82
# 63 es valido gracias a * en 81,27
# 501 es valido gracias a * en 81,27
# 529 es valido gracias a * en 81,35
# 695 es valido gracias a / en 82,54
# 320 es valido gracias a * en 83,98
# 211 es valido gracias a * en 83,125
# 55 es valido gracias a * en 83,125
# 533 es valido gracias a + en 83,131
# Hay None
#
# ROW 83
# 457 es valido gracias a * en 84,14
# 375 es valido gracias a # en 83,68
# 961 es valido gracias a * en 83,82
# 720 es valido gracias a * en 82,88
# 542 es valido gracias a * en 84,117
# 327 es valido gracias a * en 84,135
# Hay None
#
# ROW 84
# 396 es valido gracias a - en 85,11
# 476 es valido gracias a * en 85,19
# 774 es valido gracias a * en 85,19
# 680 es valido gracias a & en 85,25
# 189 es valido gracias a @ en 84,31
# 669 es valido gracias a = en 83,41
# 936 es valido gracias a * en 85,56
# 195 es valido gracias a * en 83,82
# 405 es valido gracias a * en 85,95
# 926 es valido gracias a * en 83,98
# 213 es valido gracias a * en 85,104
# Hay None
#
# ROW 85
# 22 es valido gracias a * en 86,45
# 732 es valido gracias a & en 86,52
# 121 es valido gracias a $ en 85,64
# 200 es valido gracias a * en 86,72
# 522 es valido gracias a * en 84,117
# 825 es valido gracias a * en 86,123
# 77 es valido gracias a * en 86,126
# Hay None
#
# ROW 86
# 272 es valido gracias a - en 85,3
# 925 es valido gracias a $ en 85,37
# 378 es valido gracias a * en 86,45
# 53 es valido gracias a * en 85,56
# 605 es valido gracias a & en 87,76
# 329 es valido gracias a - en 85,87
# 116 es valido gracias a / en 87,89
# 501 es valido gracias a * en 85,95
# 765 es valido gracias a * en 85,104
# 537 es valido gracias a * en 87,111
# 680 es valido gracias a * en 87,117
# Hay None
#
# ROW 87
# 817 es valido gracias a = en 88,3
# 209 es valido gracias a # en 86,21
# 690 es valido gracias a * en 88,48
# 573 es valido gracias a * en 86,72
# 48 es valido gracias a = en 86,99
# 169 es valido gracias a * en 86,123
# 581 es valido gracias a * en 86,126
# 537 es valido gracias a # en 86,136
# Hay None
#
# ROW 88
# 747 es valido gracias a * en 89,6
# 171 es valido gracias a * en 89,23
# 70 es valido gracias a * en 89,27
# 990 es valido gracias a = en 89,37
# 529 es valido gracias a * en 89,64
# 482 es valido gracias a @ en 89,82
# 531 es valido gracias a * en 87,111
# 53 es valido gracias a * en 87,117
# 211 es valido gracias a # en 88,131
# Hay None
#
# ROW 89
# 470 es valido gracias a * en 90,11
# 812 es valido gracias a * en 90,29
# 664 es valido gracias a * en 90,35
# 141 es valido gracias a * en 88,48
# 888 es valido gracias a * en 90,57
# 312 es valido gracias a * en 90,85
# 9 es valido gracias a * en 89,92
# 860 es valido gracias a * en 89,92
# Hay None
#
# ROW 90
# 906 es valido gracias a * en 89,6
# 810 es valido gracias a @ en 91,18
# 966 es valido gracias a * en 89,23
# 616 es valido gracias a * en 89,64
# 327 es valido gracias a - en 90,79
# 80 es valido gracias a * en 91,116
# 655 es valido gracias a / en 89,123
# Hay None
#
# ROW 91
# 459 es valido gracias a * en 90,11
# 185 es valido gracias a * en 90,29
# 894 es valido gracias a * en 90,35
# 891 es valido gracias a $ en 92,41
# 254 es valido gracias a * en 90,57
# 262 es valido gracias a * en 92,104
# 602 es valido gracias a * en 91,116
# Hay None
#
# ROW 92
# 55 es valido gracias a * en 92,48
# 155 es valido gracias a @ en 93,62
# 248 es valido gracias a * en 92,85
# 600 es valido gracias a * en 92,85
# 880 es valido gracias a * en 93,131
# Hay None
#
# ROW 93
# 459 es valido gracias a * en 94,6
# 928 es valido gracias a * en 94,22
# 900 es valido gracias a * en 93,53
# 27 es valido gracias a * en 94,69
# 434 es valido gracias a * en 92,104
# 402 es valido gracias a * en 94,110
# 840 es valido gracias a * en 92,120
# 816 es valido gracias a * en 92,120
# Hay None
#
# ROW 94
# 241 es valido gracias a * en 95,18
# 70 es valido gracias a * en 95,28
# 465 es valido gracias a * en 95,28
# 668 es valido gracias a * en 95,37
# 110 es valido gracias a = en 94,45
# 905 es valido gracias a * en 93,53
# 252 es valido gracias a * en 95,65
# 74 es valido gracias a * en 95,95
# 817 es valido gracias a * en 93,131
# 290 es valido gracias a * en 95,133
# Hay None
#
# ROW 95
# 540 es valido gracias a * en 96,4
# 224 es valido gracias a * en 94,6
# 42 es valido gracias a * en 94,22
# 705 es valido gracias a * en 96,54
# 128 es valido gracias a * en 94,69
# 758 es valido gracias a = en 95,79
# 512 es valido gracias a % en 94,84
# 884 es valido gracias a % en 96,86
# 648 es valido gracias a * en 95,101
# 259 es valido gracias a * en 94,110
# 486 es valido gracias a % en 96,118
# 627 es valido gracias a + en 96,126
# Hay None
#
# ROW 96
# 467 es valido gracias a * en 95,18
# 462 es valido gracias a * en 95,37
# 296 es valido gracias a * en 96,49
# 211 es valido gracias a * en 96,49
# 283 es valido gracias a * en 95,65
# 488 es valido gracias a & en 95,74
# 796 es valido gracias a * en 95,95
# 774 es valido gracias a * en 95,101
# 200 es valido gracias a * en 97,129
# 87 es valido gracias a * en 95,133
# Hay None
#
# ROW 97
# 663 es valido gracias a * en 96,4
# 961 es valido gracias a $ en 97,20
# 579 es valido gracias a * en 98,29
# 189 es valido gracias a $ en 98,79
# 71 es valido gracias a - en 98,91
# Hay None
#
# ROW 98
# 645 es valido gracias a + en 99,16
# 700 es valido gracias a * en 99,41
# 886 es valido gracias a & en 99,46
# 806 es valido gracias a & en 99,51
# 581 es valido gracias a * en 97,56
# 610 es valido gracias a * en 97,56
# 132 es valido gracias a * en 99,68
# 379 es valido gracias a * en 99,68
# 941 es valido gracias a $ en 98,97
# 504 es valido gracias a * en 99,119
# 589 es valido gracias a * en 97,129
# Hay 528
#
# ROW 99
# 290 es valido gracias a + en 100,22
# 221 es valido gracias a * en 98,29
# 768 es valido gracias a * en 100,36
# 556 es valido gracias a + en 98,86
# 132 es valido gracias a * en 100,105
# Hay None
#
# ROW 100
# 152 es valido gracias a * en 100,36
# 448 es valido gracias a * en 99,41
# 903 es valido gracias a * en 101,57
# 339 es valido gracias a * en 101,63
# 709 es valido gracias a - en 101,80
# 991 es valido gracias a * en 101,97
# 865 es valido gracias a * en 99,119
# Hay None
#
# ROW 101
# 717 es valido gracias a $ en 101,10
# 552 es valido gracias a * en 102,28
# 458 es valido gracias a * en 102,49
# 365 es valido gracias a = en 100,72
# 762 es valido gracias a * en 102,90
# 732 es valido gracias a * en 102,90
# 690 es valido gracias a * en 100,105
# 266 es valido gracias a @ en 102,110
# 222 es valido gracias a * en 102,115
# 122 es valido gracias a * en 102,133
# Hay None
#
# ROW 102
# 414 es valido gracias a - en 101,4
# 496 es valido gracias a % en 103,16
# 712 es valido gracias a * en 103,24
# 785 es valido gracias a # en 103,38
# 79 es valido gracias a * en 101,57
# 884 es valido gracias a * en 101,63
# 991 es valido gracias a * en 103,66
# 844 es valido gracias a * en 101,97
# 782 es valido gracias a * en 103,119
# 627 es valido gracias a * en 102,133
# Hay None
#
# ROW 103
# 560 es valido gracias a + en 102,21
# 873 es valido gracias a * en 102,28
# 739 es valido gracias a = en 102,32
# 368 es valido gracias a * en 102,49
# 991 es valido gracias a * en 104,52
# 27 es valido gracias a + en 104,71
# 951 es valido gracias a / en 102,85
# 864 es valido gracias a - en 102,101
# 206 es valido gracias a * en 102,115
# 878 es valido gracias a * en 104,123
# Hay None
#
# ROW 104
# 231 es valido gracias a $ en 103,7
# 995 es valido gracias a $ en 105,13
# 865 es valido gracias a * en 103,24
# 602 es valido gracias a = en 105,42
# 379 es valido gracias a * en 103,60
# 609 es valido gracias a * en 103,60
# 935 es valido gracias a * en 103,66
# 952 es valido gracias a + en 105,97
# 884 es valido gracias a * en 103,119
# Hay None
#
# ROW 105
# 726 es valido gracias a + en 106,21
# 360 es valido gracias a = en 106,31
# 990 es valido gracias a * en 105,92
# 959 es valido gracias a @ en 104,105
# 932 es valido gracias a * en 104,123
# Hay None
#
# ROW 106
# 508 es valido gracias a $ en 107,23
# 194 es valido gracias a * en 107,37
# 30 es valido gracias a * en 106,45
# 487 es valido gracias a * en 107,70
# 171 es valido gracias a / en 107,79
# 709 es valido gracias a * en 105,92
# 495 es valido gracias a * en 107,102
# 995 es valido gracias a * en 107,112
# 464 es valido gracias a % en 107,117
# 997 es valido gracias a * en 107,129
# Hay None
#
# ROW 107
# 253 es valido gracias a * en 106,45
# 554 es valido gracias a / en 106,57
# 582 es valido gracias a * en 107,129
# 446 es valido gracias a * en 108,135
# Hay None
#
# ROW 108
# 237 es valido gracias a * en 109,22
# 32 es valido gracias a * en 108,27
# 286 es valido gracias a * en 109,35
# 259 es valido gracias a * en 107,37
# 132 es valido gracias a * en 107,54
# 236 es valido gracias a $ en 109,61
# 683 es valido gracias a * en 107,70
# 705 es valido gracias a * en 107,102
# 855 es valido gracias a $ en 108,107
# 37 es valido gracias a * en 107,112
# 476 es valido gracias a * en 107,124
# Hay None
#
# ROW 109
# 418 es valido gracias a = en 109,8
# 664 es valido gracias a * en 108,27
# 11 es valido gracias a * en 109,46
# 70 es valido gracias a * en 110,74
# 380 es valido gracias a & en 108,77
# 138 es valido gracias a * en 110,82
# 416 es valido gracias a * en 110,92
# 609 es valido gracias a & en 110,95
# 452 es valido gracias a = en 108,119
# 43 es valido gracias a # en 110,127
# 156 es valido gracias a * en 108,135
# Hay 260
#
# ROW 110
# 20 es valido gracias a * en 109,22
# 512 es valido gracias a * en 109,35
# 303 es valido gracias a * en 109,46
# 491 es valido gracias a = en 109,67
# 962 es valido gracias a & en 110,106
# Hay None
#
# ROW 111
# 646 es valido gracias a * en 112,6
# 833 es valido gracias a * en 112,12
# 348 es valido gracias a - en 110,51
# 537 es valido gracias a $ en 112,57
# 92 es valido gracias a * en 110,74
# 295 es valido gracias a * en 110,82
# 620 es valido gracias a * en 110,92
# 147 es valido gracias a = en 111,115
# 753 es valido gracias a * en 110,120
# Hay None
#
# ROW 112
# 210 es valido gracias a * en 113,31
# 350 es valido gracias a * en 113,81
# 533 es valido gracias a * en 113,104
# Hay None
#
# ROW 113
# 65 es valido gracias a * en 114,3
# 22 es valido gracias a * en 112,6
# 656 es valido gracias a * en 112,12
# 44 es valido gracias a * en 113,25
# 178 es valido gracias a * en 113,42
# 446 es valido gracias a * en 114,53
# 592 es valido gracias a * en 113,81
# 952 es valido gracias a - en 113,93
# 680 es valido gracias a = en 114,98
# 305 es valido gracias a # en 113,122
# 704 es valido gracias a + en 112,134
# Hay None
#
# ROW 114
# 422 es valido gracias a # en 113,16
# 835 es valido gracias a * en 113,25
# 126 es valido gracias a * en 113,31
# 552 es valido gracias a * en 113,42
# 543 es valido gracias a & en 115,58
# 444 es valido gracias a = en 115,78
# 995 es valido gracias a - en 115,89
# 771 es valido gracias a * en 113,104
# 480 es valido gracias a = en 113,116
# Hay None
#
# ROW 115
# 983 es valido gracias a $ en 115,29
# 5 es valido gracias a * en 116,40
# 953 es valido gracias a * en 114,53
# 216 es valido gracias a * en 116,68
# 749 es valido gracias a - en 114,71
# 232 es valido gracias a * en 116,109
# Hay None
#
# ROW 116
# 426 es valido gracias a * en 117,53
# 792 es valido gracias a % en 116,106
# 39 es valido gracias a * en 117,130
# Hay None
#
# ROW 117
# 480 es valido gracias a + en 118,3
# 674 es valido gracias a + en 118,12
# 149 es valido gracias a + en 117,19
# 740 es valido gracias a * en 116,40
# 251 es valido gracias a * en 117,53
# 920 es valido gracias a * en 118,59
# 552 es valido gracias a * en 116,68
# 713 es valido gracias a $ en 116,94
# 639 es valido gracias a * en 116,109
# Hay None
#
# ROW 118
# 951 es valido gracias a $ en 118,32
# 968 es valido gracias a # en 117,48
# 750 es valido gracias a & en 119,107
# 479 es valido gracias a * en 119,117
# 770 es valido gracias a * en 117,130
# 959 es valido gracias a + en 119,136
# Hay None
#
# ROW 119
# 54 es valido gracias a * en 119,22
# 489 es valido gracias a * en 119,22
# 355 es valido gracias a * en 118,46
# 782 es valido gracias a * en 118,59
# 50 es valido gracias a * en 120,63
# 900 es valido gracias a / en 120,82
# 770 es valido gracias a & en 120,87
# 639 es valido gracias a # en 120,101
# 942 es valido gracias a * en 120,112
# 39 es valido gracias a * en 119,117
# 477 es valido gracias a * en 120,127
# Hay None
#
# ROW 120
# 888 es valido gracias a * en 121,6
# 412 es valido gracias a + en 119,28
# 123 es valido gracias a % en 120,67
# 315 es valido gracias a * en 121,93
# Hay None
#
# ROW 121
# 793 es valido gracias a * en 122,34
# 402 es valido gracias a * en 122,41
# 807 es valido gracias a * en 121,48
# 854 es valido gracias a @ en 121,58
# 115 es valido gracias a * en 120,63
# 204 es valido gracias a * en 122,97
# 208 es valido gracias a & en 122,107
# 928 es valido gracias a * en 120,112
# 121 es valido gracias a * en 120,127
# Hay None
#
# ROW 122
# 880 es valido gracias a = en 122,14
# 818 es valido gracias a * en 123,19
# 982 es valido gracias a @ en 123,25
# 923 es valido gracias a * en 121,48
# 809 es valido gracias a = en 121,89
# 962 es valido gracias a * en 121,93
# Hay None
#
# ROW 123
# 957 es valido gracias a * en 123,6
# 511 es valido gracias a * en 123,6
# 436 es valido gracias a * en 123,19
# 704 es valido gracias a * en 122,34
# 84 es valido gracias a / en 123,74
# 496 es valido gracias a * en 124,85
# 917 es valido gracias a * en 122,97
# Hay None
#
# ROW 124
# 785 es valido gracias a * en 124,43
# 848 es valido gracias a - en 123,58
# 506 es valido gracias a / en 123,67
# 116 es valido gracias a * en 124,85
# Hay None
#
# ROW 125
# 694 es valido gracias a & en 126,9
# 257 es valido gracias a * en 126,15
# 15 es valido gracias a * en 124,43
# 176 es valido gracias a * en 126,58
# 593 es valido gracias a = en 124,105
# 168 es valido gracias a # en 124,108
# 914 es valido gracias a - en 126,115
# 230 es valido gracias a - en 125,122
# 500 es valido gracias a = en 126,136
# Hay None
#
# ROW 126
# 427 es valido gracias a & en 127,6
# 233 es valido gracias a @ en 127,80
# 616 es valido gracias a & en 126,89
# 299 es valido gracias a * en 126,97
# Hay None
#
# ROW 127
# 598 es valido gracias a * en 126,15
# 571 es valido gracias a / en 127,31
# 60 es valido gracias a * en 128,38
# 897 es valido gracias a * en 128,50
# 911 es valido gracias a * en 126,58
# 34 es valido gracias a * en 128,63
# 106 es valido gracias a = en 126,72
# 713 es valido gracias a % en 126,76
# 933 es valido gracias a * en 128,113
# 288 es valido gracias a * en 128,126
# Hay None
#
# ROW 128
# 314 es valido gracias a * en 129,4
# 563 es valido gracias a + en 129,23
# 591 es valido gracias a * en 128,126
# Hay None
#
# ROW 129
# 274 es valido gracias a * en 130,14
# 875 es valido gracias a * en 130,14
# 114 es valido gracias a & en 128,26
# 105 es valido gracias a * en 128,38
# 763 es valido gracias a * en 130,46
# 319 es valido gracias a * en 128,50
# 730 es valido gracias a * en 129,70
# 158 es valido gracias a * en 130,82
# 487 es valido gracias a - en 130,104
# 505 es valido gracias a * en 128,113
# Hay None
#
# ROW 130
# 439 es valido gracias a * en 129,4
# 595 es valido gracias a * en 131,53
# 190 es valido gracias a * en 131,61
# 173 es valido gracias a * en 131,61
# 653 es valido gracias a * en 129,70
# 882 es valido gracias a * en 131,89
# 812 es valido gracias a * en 131,89
# 230 es valido gracias a * en 130,98
# 522 es valido gracias a - en 131,117
# 192 es valido gracias a # en 131,135
# Hay None
#
# ROW 131
# 554 es valido gracias a * en 132,15
# 825 es valido gracias a $ en 132,22
# 845 es valido gracias a # en 132,27
# 797 es valido gracias a * en 130,37
# 572 es valido gracias a * en 130,37
# 814 es valido gracias a * en 130,46
# 167 es valido gracias a * en 130,82
# 581 es valido gracias a * en 130,98
# 330 es valido gracias a = en 130,124
# Hay None
#
# ROW 132
# 82 es valido gracias a - en 133,9
# 318 es valido gracias a * en 131,53
# 326 es valido gracias a * en 131,74
# 924 es valido gracias a * en 131,74
# 288 es valido gracias a * en 133,94
# 44 es valido gracias a * en 133,109
# Hay None
#
# ROW 133
# 526 es valido gracias a * en 132,15
# 981 es valido gracias a = en 133,42
# 959 es valido gracias a * en 134,57
# 915 es valido gracias a * en 132,104
# 116 es valido gracias a * en 132,104
# 577 es valido gracias a + en 132,133
# Hay None
#
# ROW 134
# 130 es valido gracias a - en 133,5
# 330 es valido gracias a @ en 134,35
# 679 es valido gracias a & en 135,61
# 999 es valido gracias a % en 135,75
# 344 es valido gracias a * en 133,80
# 611 es valido gracias a * en 133,80
# 432 es valido gracias a * en 133,94
# 690 es valido gracias a $ en 133,114
# 502 es valido gracias a = en 133,118
# Hay None
#
# ROW 135
# 476 es valido gracias a * en 136,12
# 303 es valido gracias a * en 136,89
# 731 es valido gracias a $ en 136,97
# 681 es valido gracias a & en 136,106
# Hay None
#
# ROW 136
# 791 es valido gracias a @ en 136,4
# 152 es valido gracias a # en 135,19
# 397 es valido gracias a & en 137,24
# 904 es valido gracias a % en 137,51
# 225 es valido gracias a * en 137,73
# Hay None
#
# ROW 137
# 995 es valido gracias a * en 136,12
# 558 es valido gracias a * en 136,31
# 857 es valido gracias a * en 136,31
# 141 es valido gracias a * en 138,41
# 803 es valido gracias a * en 138,46
# 199 es valido gracias a % en 138,67
# 573 es valido gracias a * en 138,79
# 315 es valido gracias a * en 136,89
# Hay None
#
# ROW 138
# 158 es valido gracias a * en 138,41
# 737 es valido gracias a - en 137,56
# 399 es valido gracias a * en 137,73
# 47 es valido gracias a # en 138,98
# 100 es valido gracias a * en 137,108
# 333 es valido gracias a # en 138,130
# Hay None
#
# ROW 139
# 665 es valido gracias a * en 138,46
# 563 es valido gracias a * en 138,79
# Hay None
# 534316
# '\n467..114.5\n...*6...66\n..35..633.\n......#...\n617*......\n.....+.58.\n..592.....\n......755.\n...$.*....\n.664.598..\n'

# %%
print ("\n".join(puzzle.test))
# Out:
# 467..114..
# ...*......
# ..35..633.
# ......#...
# 617*......
# .....+.58.
# ..592.....
# ......755.
# ...$.*....
# .664.598..
